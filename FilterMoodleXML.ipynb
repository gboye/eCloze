# %%
from lxml import etree
import bs4
parser = etree.XMLParser(remove_blank_text=True)

# %%
xmlTRS=etree.parse("/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/21-K2/Traductions-Version-RX-EnfantGarçon.xml",parser)

# %%
rootXML=xmlTRS.getroot()

# %%
for answer in rootXML.findall("question/answer/text"):
    if u"gar&#231;on" in etree.tostring(answer):
        print etree.tostring(answer)
# Out:
# <text>Ce gar&#231;on de la maison de Nicole achetait les autruches pour les deux filles de Nabil.</text>
# <text>Ce\s+gar&#231;on\s+de\s+la\s+maison\s+de\s+Nicole\s+achetait\s+les\s+autruches\s+pour\s+les\s+deux\s+filles\s+de\s+Nabil.</text>
# <text>Les deux gar&#231;ons de la maison de Nicole ach&#232;tent deux autruches pour des filles de Nabil.</text>
# <text>Les\s+deux\s+gar&#231;ons\s+de\s+la\s+maison\s+de\s+Nicole\s+ach&#232;tent\s+deux\s+autruches\s+pour\s+des\s+filles\s+de\s+Nabil.</text>
# <text>Les filles de Nabil ach&#232;tent ces autruches pour ces gar&#231;ons de la maison de Nicole.</text>
# <text>Les\s+filles\s+de\s+Nabil\s+ach&#232;tent\s+ces\s+autruches\s+pour\s+ces\s+gar&#231;ons\s+de\s+la\s+maison\s+de\s+Nicole.</text>
# <text>Ces deux gar&#231;ons de la maison de Nicole ach&#232;tent ces deux autruches pour deux filles de Nabil.</text>
# ...
