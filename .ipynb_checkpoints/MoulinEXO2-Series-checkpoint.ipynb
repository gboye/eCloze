# %%
#import re
import sys, codecs, optparse, glob, os
import string
import random
from ToolsMoodleXML2 import *

# %%
dossier="/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/Kalaba-Project/16-K1"
enonces=["Forme-Radical",
         "Forme-Traduction","Traduction-Radical",
#         "Forme-Traduction-MC","Traduction-Radical-MC",
#         "Forme-Proprietes",
         "Glose-Decoupe","Decoupe-Glose-MC","Decoupe-Glose"
        ]
enonces=[
         "Forme-Traduction","Traduction-Radical",
#         "Forme-Traduction-MC","Traduction-Radical-MC",
#         "Forme-Proprietes",
         "Proprietes-Forme",
#         "Glose-Decoupe",
         "Decoupe-Glose-MC",
#         "Decoupe-Glose"
        ]
theme="16-K1-A1"

# %%
from os.path import expanduser
home = expanduser("~")
repertoire=home+dossier
base=repertoire+"/"

# %%
from ToolsMoodleXML import *
import yaml

# %%
def donneesEX():
    titre=[]
    result=""
    i=0
    for ligne in donneesLignes:
        i+=1
        if ligne.startswith("#EX;"):
            if result!="":
                donnees.append({"-".join(titre):result})
            titre=[]
            result={"boucle":[],"conclusion":[]}
            temp=ligne.strip().split(";")
            if len(temp)>1 and temp[1]!="":
                result["conclusion"]=temp[1:]
        elif ligne.startswith("#"):
            pass
        else:
            temp=ligne.strip().split(";")
            result["boucle"].append(temp)
            titre.append(makeChamps(configuration[u"Titre"],temp).encode('utf8'))
    donnees.append({"-".join(titre):result})

def donneesNoEX():
    if titreNoEX:
        debut=1
    else:
        debut=0
    for ligne in donneesLignes[debut:]:
        if not (ligne.strip().strip(";")=="" or ligne.startswith("#")):
            temp=ligne.strip().split(";")
            result={"boucle":[temp],"conclusion":[]}
            titre=makeChamps(configuration[u"Titre"],temp).encode('utf8')
            donnees.append({titre:result})
    return

# %%
for enonce in enonces:
    yamlFichier=base+theme+"-"+enonce+".yaml"
    csvFichier=base+theme+".txt"
    boolEX=False
    titreNoEX=False
            
    with open(yamlFichier, 'r') as stream:
        configuration=yaml.load(stream)

    with open(csvFichier, 'r') as file:
        donneesLignes=file.readlines()

    donnees=[]
    if boolEX or donneesLignes[0].startswith("#EX;"):
    #    print "avec #EX;"
        donneesEX()
    else:
    #    print "sans #EX;"
        donneesNoEX()

        
    categorie=configuration[u"Catégorie"]
    #donnees=configuration[u"Données"]
    consigne=configuration[u"Boucle"][u"contenu"]
    boucleWrap=[configuration[u"Boucle"][u"début"],configuration[u"Boucle"]["fin"]]
    boucleCLOZE=configuration[u"Boucle"][u"Cloze"]
    globalWrap=[configuration[u"Décor"][u"fond"]+configuration[u"Décor"][u"entete"]+configuration[u"Global"][u"début"],configuration[u"Global"]["fin"]]
    if "Conclusion" in configuration:
        conclusion=[configuration[u"Conclusion"][u"début"],configuration[u"Conclusion"]["contenu"],configuration[u"Conclusion"]["fin"]]
        conclusionCLOZE=configuration[u"Conclusion"][u"Cloze"]
    else:
        conclusion=["","",""]
        conclusionCLOZE=[]
    questions=XMLSeries(categorie)
    questionsConsigne=ClozeConsigne(consigne,boucleWrap=boucleWrap,globalWrap=globalWrap,conclusion=conclusion)
    serie=ClozeSerie(configuration[u"Boucle"][u"Cloze"],conclusionCLOZE)

    for exercices in donnees:
    #    print "exercices",exercices
        for exercice in exercices:
    #        print "exercice",exercice
            exerciceBoucle=exercices[exercice]["boucle"]
            exerciceConclusion=exercices[exercice]["conclusion"]
            serie.addExercice(Exercice(exerciceBoucle,exerciceConclusion,exercice.decode('utf8')))

    for exercice in serie.makeSerie(questionsConsigne):
    #    print exercice.corps
        questions.addExercice(exercice)

    xmlOutput=MoodleXML()
    xmlOutput.addQuiz(questions.getSeries())

    xmlFichier=yamlFichier.split(".")[0]+".xml"

    with codecs.open(xmlFichier, 'w',encoding="utf8") as output:
    #    print [questions.getClozes()]
        output.write(xmlOutput.getXML())
# Out:
# courirPrsTroisSg; courir; VER; tras; ; trasi; tras-i; VER, CF=V1,  Temps=PRS, Pers=3Sg; courir.V1-3Sg.V1; 3; courir; .V1; -3Sg.V1
# courirPrsTroisDu; courir; VER; tras; ; trasin; tras-in; VER, CF=V1,  Temps=PRS, Pers=3Du; courir.V1-3Du.V1; 3; courir; .V1; -3Du.V1
# courirPrsTroisPl; courir; VER; tras; ; trasin; tras-in; VER, CF=V1,  Temps=PRS, Pers=3Pl; courir.V1-3Pl.V1; 3; courir; .V1; -3Pl.V1
# courirPstTroisSg; courir; VER; tras; ; trasise; tras-is-e; VER, CF=V1,  Temps=PST, Pers=3Sg; courir.V1-PST.V1-3Sg.V1.PST; 4; courir; .V1; -PST.V1; -3Sg.V1.PST
# courirPstTroisDu; courir; VER; tras; ; trasisin; tras-is-in; VER, CF=V1,  Temps=PST, Pers=3Du; courir.V1-PST.V1-3Du.V1; 4; courir; .V1; -PST.V1; -3Du.V1
# courirPstTroisPl; courir; VER; tras; ; trasisin; tras-is-in; VER, CF=V1,  Temps=PST, Pers=3Pl; courir.V1-PST.V1-3Pl.V1; 4; courir; .V1; -PST.V1; -3Pl.V1
# etrePrsTroisSg; être; VER; sum; ; sumi; sum-i; VER, CF=V1,  Temps=PRS, Pers=3Sg; être.V1-3Sg.V1; 3; être; .V1; -3Sg.V1
# etrePrsTroisDu; être; VER; sum; ; sumin; sum-in; VER, CF=V1,  Temps=PRS, Pers=3Du; être.V1-3Du.V1; 3; être; .V1; -3Du.V1
# etrePrsTroisPl; être; VER; sum; ; sumin; sum-in; VER, CF=V1,  Temps=PRS, Pers=3Pl; être.V1-3Pl.V1; 3; être; .V1; -3Pl.V1
# etrePstTroisSg; être; VER; sum; ; sumise; sum-is-e; VER, CF=V1,  Temps=PST, Pers=3Sg; être.V1-PST.V1-3Sg.V1.PST; 4; être; .V1; -PST.V1; -3Sg.V1.PST
# etrePstTroisDu; être; VER; sum; ; sumisin; sum-is-in; VER, CF=V1,  Temps=PST, Pers=3Du; être.V1-PST.V1-3Du.V1; 4; être; .V1; -PST.V1; -3Du.V1
# etrePstTroisPl; être; VER; sum; ; sumisin; sum-is-in; VER, CF=V1,  Temps=PST, Pers=3Pl; être.V1-PST.V1-3Pl.V1; 4; être; .V1; -PST.V1; -3Pl.V1
# fuirPrsTroisSg; fuir; VER; eʃap; ; eʃapi; eʃap-i; VER, CF=V1,  Temps=PRS, Pers=3Sg; fuir.V1-3Sg.V1; 3; fuir; .V1; -3Sg.V1
# fuirPrsTroisDu; fuir; VER; eʃap; ; eʃapin; eʃap-in; VER, CF=V1,  Temps=PRS, Pers=3Du; fuir.V1-3Du.V1; 3; fuir; .V1; -3Du.V1
# fuirPrsTroisPl; fuir; VER; eʃap; ; eʃapin; eʃap-in; VER, CF=V1,  Temps=PRS, Pers=3Pl; fuir.V1-3Pl.V1; 3; fuir; .V1; -3Pl.V1
# fuirPstTroisSg; fuir; VER; eʃap; ; eʃapise; eʃap-is-e; VER, CF=V1,  Temps=PST, Pers=3Sg; fuir.V1-PST.V1-3Sg.V1.PST; 4; fuir; .V1; -PST.V1; -3Sg.V1.PST
# fuirPstTroisDu; fuir; VER; eʃap; ; eʃapisin; eʃap-is-in; VER, CF=V1,  Temps=PST, Pers=3Du; fuir.V1-PST.V1-3Du.V1; 4; fuir; .V1; -PST.V1; -3Du.V1
# fuirPstTroisPl; fuir; VER; eʃap; ; eʃapisin; eʃap-is-in; VER, CF=V1,  Temps=PST, Pers=3Pl; fuir.V1-PST.V1-3Pl.V1; 4; fuir; .V1; -PST.V1; -3Pl.V1
# apporterPrsTroisSg; apporter; VER; amne; ; amnei; amne-i; VER, CF=V1,  Temps=PRS, Pers=3Sg; apporter.V1-3Sg.V1; 3; apporter; .V1; -3Sg.V1
# apporterPrsTroisDu; apporter; VER; amne; ; amnein; amne-in; VER, CF=V1,  Temps=PRS, Pers=3Du; apporter.V1-3Du.V1; 3; apporter; .V1; -3Du.V1
# apporterPrsTroisPl; apporter; VER; amne; ; amnein; amne-in; VER, CF=V1,  Temps=PRS, Pers=3Pl; apporter.V1-3Pl.V1; 3; apporter; .V1; -3Pl.V1
# apporterPstTroisSg; apporter; VER; amne; ; amneise; amne-is-e; VER, CF=V1,  Temps=PST, Pers=3Sg; apporter.V1-PST.V1-3Sg.V1.PST; 4; apporter; .V1; -PST.V1; -3Sg.V1.PST
# apporterPstTroisDu; apporter; VER; amne; ; amneisin; amne-is-in; VER, CF=V1,  Temps=PST, Pers=3Du; apporter.V1-PST.V1-3Du.V1; 4; apporter; .V1; -PST.V1; -3Du.V1
# apporterPstTroisPl; apporter; VER; amne; ; amneisin; amne-is-in; VER, CF=V1,  Temps=PST, Pers=3Pl; apporter.V1-PST.V1-3Pl.V1; 4; apporter; .V1; -PST.V1; -3Pl.V1
# devorerPrsTroisSg; dévorer; VER; deʃik; ; deʃiki; deʃik-i; VER, CF=V1,  Temps=PRS, Pers=3Sg; dévorer.V1-3Sg.V1; 3; dévorer; .V1; -3Sg.V1
# devorerPrsTroisDu; dévorer; VER; deʃik; ; deʃikin; deʃik-in; VER, CF=V1,  Temps=PRS, Pers=3Du; dévorer.V1-3Du.V1; 3; dévorer; .V1; -3Du.V1
# devorerPrsTroisPl; dévorer; VER; deʃik; ; deʃikin; deʃik-in; VER, CF=V1,  Temps=PRS, Pers=3Pl; dévorer.V1-3Pl.V1; 3; dévorer; .V1; -3Pl.V1
# devorerPstTroisSg; dévorer; VER; deʃik; ; deʃikise; deʃik-is-e; VER, CF=V1,  Temps=PST, Pers=3Sg; dévorer.V1-PST.V1-3Sg.V1.PST; 4; dévorer; .V1; -PST.V1; -3Sg.V1.PST
# devorerPstTroisDu; dévorer; VER; deʃik; ; deʃikisin; deʃik-is-in; VER, CF=V1,  Temps=PST, Pers=3Du; dévorer.V1-PST.V1-3Du.V1; 4; dévorer; .V1; -PST.V1; -3Du.V1
# devorerPstTroisPl; dévorer; VER; deʃik; ; deʃikisin; deʃik-is-in; VER, CF=V1,  Temps=PST, Pers=3Pl; dévorer.V1-PST.V1-3Pl.V1; 4; dévorer; .V1; -PST.V1; -3Pl.V1
# prendrePrsTroisSg; prendre; VER; ʃop; ; ʃopi; ʃop-i; VER, CF=V1,  Temps=PRS, Pers=3Sg; prendre.V1-3Sg.V1; 3; prendre; .V1; -3Sg.V1
# prendrePrsTroisDu; prendre; VER; ʃop; ; ʃopin; ʃop-in; VER, CF=V1,  Temps=PRS, Pers=3Du; prendre.V1-3Du.V1; 3; prendre; .V1; -3Du.V1
# prendrePrsTroisPl; prendre; VER; ʃop; ; ʃopin; ʃop-in; VER, CF=V1,  Temps=PRS, Pers=3Pl; prendre.V1-3Pl.V1; 3; prendre; .V1; -3Pl.V1
# prendrePstTroisSg; prendre; VER; ʃop; ; ʃopise; ʃop-is-e; VER, CF=V1,  Temps=PST, Pers=3Sg; prendre.V1-PST.V1-3Sg.V1.PST; 4; prendre; .V1; -PST.V1; -3Sg.V1.PST
# prendrePstTroisDu; prendre; VER; ʃop; ; ʃopisin; ʃop-is-in; VER, CF=V1,  Temps=PST, Pers=3Du; prendre.V1-PST.V1-3Du.V1; 4; prendre; .V1; -PST.V1; -3Du.V1
# prendrePstTroisPl; prendre; VER; ʃop; ; ʃopisin; ʃop-is-in; VER, CF=V1,  Temps=PST, Pers=3Pl; prendre.V1-PST.V1-3Pl.V1; 4; prendre; .V1; -PST.V1; -3Pl.V1
# jeterPrsTroisSg; jeter; VER; teʒ; ; teʒi; teʒ-i; VER, CF=V1,  Temps=PRS, Pers=3Sg; jeter.V1-3Sg.V1; 3; jeter; .V1; -3Sg.V1
# jeterPrsTroisDu; jeter; VER; teʒ; ; teʒin; teʒ-in; VER, CF=V1,  Temps=PRS, Pers=3Du; jeter.V1-3Du.V1; 3; jeter; .V1; -3Du.V1
# jeterPrsTroisPl; jeter; VER; teʒ; ; teʒin; teʒ-in; VER, CF=V1,  Temps=PRS, Pers=3Pl; jeter.V1-3Pl.V1; 3; jeter; .V1; -3Pl.V1
# jeterPstTroisSg; jeter; VER; teʒ; ; teʒise; teʒ-is-e; VER, CF=V1,  Temps=PST, Pers=3Sg; jeter.V1-PST.V1-3Sg.V1.PST; 4; jeter; .V1; -PST.V1; -3Sg.V1.PST
# jeterPstTroisDu; jeter; VER; teʒ; ; teʒisin; teʒ-is-in; VER, CF=V1,  Temps=PST, Pers=3Du; jeter.V1-PST.V1-3Du.V1; 4; jeter; .V1; -PST.V1; -3Du.V1
# jeterPstTroisPl; jeter; VER; teʒ; ; teʒisin; teʒ-is-in; VER, CF=V1,  Temps=PST, Pers=3Pl; jeter.V1-PST.V1-3Pl.V1; 4; jeter; .V1; -PST.V1; -3Pl.V1
# disparaitrePrsTroisSg; disparaître; VER; estomp; ; estompi; estomp-i; VER, CF=V1,  Temps=PRS, Pers=3Sg; disparaître.V1-3Sg.V1; 3; disparaître; .V1; -3Sg.V1
# disparaitrePrsTroisDu; disparaître; VER; estomp; ; estompin; estomp-in; VER, CF=V1,  Temps=PRS, Pers=3Du; disparaître.V1-3Du.V1; 3; disparaître; .V1; -3Du.V1
# disparaitrePrsTroisPl; disparaître; VER; estomp; ; estompin; estomp-in; VER, CF=V1,  Temps=PRS, Pers=3Pl; disparaître.V1-3Pl.V1; 3; disparaître; .V1; -3Pl.V1
# disparaitrePstTroisSg; disparaître; VER; estomp; ; estompise; estomp-is-e; VER, CF=V1,  Temps=PST, Pers=3Sg; disparaître.V1-PST.V1-3Sg.V1.PST; 4; disparaître; .V1; -PST.V1; -3Sg.V1.PST
# disparaitrePstTroisDu; disparaître; VER; estomp; ; estompisin; estomp-is-in; VER, CF=V1,  Temps=PST, Pers=3Du; disparaître.V1-PST.V1-3Du.V1; 4; disparaître; .V1; -PST.V1; -3Du.V1
# disparaitrePstTroisPl; disparaître; VER; estomp; ; estompisin; estomp-is-in; VER, CF=V1,  Temps=PST, Pers=3Pl; disparaître.V1-PST.V1-3Pl.V1; 4; disparaître; .V1; -PST.V1; -3Pl.V1
# sortirPrsTroisSg; sortir; VER; kitas; ; kitasi; kitas-i; VER, CF=V1,  Temps=PRS, Pers=3Sg; sortir.V1-3Sg.V1; 3; sortir; .V1; -3Sg.V1
# sortirPrsTroisDu; sortir; VER; kitas; ; kitasin; kitas-in; VER, CF=V1,  Temps=PRS, Pers=3Du; sortir.V1-3Du.V1; 3; sortir; .V1; -3Du.V1
# sortirPrsTroisPl; sortir; VER; kitas; ; kitasin; kitas-in; VER, CF=V1,  Temps=PRS, Pers=3Pl; sortir.V1-3Pl.V1; 3; sortir; .V1; -3Pl.V1
# sortirPstTroisSg; sortir; VER; kitas; ; kitasise; kitas-is-e; VER, CF=V1,  Temps=PST, Pers=3Sg; sortir.V1-PST.V1-3Sg.V1.PST; 4; sortir; .V1; -PST.V1; -3Sg.V1.PST
# sortirPstTroisDu; sortir; VER; kitas; ; kitasisin; kitas-is-in; VER, CF=V1,  Temps=PST, Pers=3Du; sortir.V1-PST.V1-3Du.V1; 4; sortir; .V1; -PST.V1; -3Du.V1
# sortirPstTroisPl; sortir; VER; kitas; ; kitasisin; kitas-is-in; VER, CF=V1,  Temps=PST, Pers=3Pl; sortir.V1-PST.V1-3Pl.V1; 4; sortir; .V1; -PST.V1; -3Pl.V1
# passerPstTroisSg; passer; VER; derul; ; derula; derula; VER, CF=V2,  Temps=PST, Pers=3Sg; passer.V2-PST.V2; 3; passer; .V2; -PST.V2
# passerPstTroisDu; passer; VER; derul; ; derulan; derul-a-n; VER, CF=V2,  Temps=PST, Pers=3Du; passer.V2-PST.V2-3Du.V2.PST; 4; passer; .V2; -PST.V2; -3Du.V2.PST
# passerPstTroisPl; passer; VER; derul; ; derulan; derul-a-n; VER, CF=V2,  Temps=PST, Pers=3Pl; passer.V2-PST.V2-3Pl.V2.PST; 4; passer; .V2; -PST.V2; -3Pl.V2.PST
# sortMSg; sort; NOM; tileʒo; ; tileʒo; tileʒo; NOM, CF=N1,  Genre=M, Nombre=Sg; sort.M.N1; 2; sort; .M.N1
# sortMDu; sort; NOM; tileʒo; ; tileʒol; tileʒo-l; NOM, CF=N1,  Genre=M, Nombre=Du; sort.M.N1-Du; 3; sort; .M.N1; -Du
# sortMPl; sort; NOM; tileʒo; ; tileʒos; tileʒo-s; NOM, CF=N1,  Genre=M, Nombre=Pl; sort.M.N1-Pl; 3; sort; .M.N1; -Pl
# corpsMSg; corps; NOM; skeleto; ; skeleto; skeleto; NOM, CF=N1,  Genre=M, Nombre=Sg; corps.M.N1; 2; corps; .M.N1
# corpsMDu; corps; NOM; skeleto; ; skeletol; skeleto-l; NOM, CF=N1,  Genre=M, Nombre=Du; corps.M.N1-Du; 3; corps; .M.N1; -Du
# corpsMPl; corps; NOM; skeleto; ; skeletos; skeleto-s; NOM, CF=N1,  Genre=M, Nombre=Pl; corps.M.N1-Pl; 3; corps; .M.N1; -Pl
# villageMSg; village; NOM; amo; ; amo; amo; NOM, CF=N1,  Genre=M, Nombre=Sg; village.M.N1; 2; village; .M.N1
# villageMDu; village; NOM; amo; ; amol; amo-l; NOM, CF=N1,  Genre=M, Nombre=Du; village.M.N1-Du; 3; village; .M.N1; -Du
# villageMPl; village; NOM; amo; ; amos; amo-s; NOM, CF=N1,  Genre=M, Nombre=Pl; village.M.N1-Pl; 3; village; .M.N1; -Pl
# visageMSg; visage; NOM; masko; ; masko; masko; NOM, CF=N1,  Genre=M, Nombre=Sg; visage.M.N1; 2; visage; .M.N1
# visageMDu; visage; NOM; masko; ; maskol; masko-l; NOM, CF=N1,  Genre=M, Nombre=Du; visage.M.N1-Du; 3; visage; .M.N1; -Du
# visageMPl; visage; NOM; masko; ; maskos; masko-s; NOM, CF=N1,  Genre=M, Nombre=Pl; visage.M.N1-Pl; 3; visage; .M.N1; -Pl
# coupMSg; coup; NOM; frapo; ; frapo; frapo; NOM, CF=N1,  Genre=M, Nombre=Sg; coup.M.N1; 2; coup; .M.N1
# coupMDu; coup; NOM; frapo; ; frapol; frapo-l; NOM, CF=N1,  Genre=M, Nombre=Du; coup.M.N1-Du; 3; coup; .M.N1; -Du
# coupMPl; coup; NOM; frapo; ; frapos; frapo-s; NOM, CF=N1,  Genre=M, Nombre=Pl; coup.M.N1-Pl; 3; coup; .M.N1; -Pl
# villageoisMSg; villageois; NOM; abito; ; abito; abito; NOM, CF=N1,  Genre=M, Nombre=Sg; villageois.M.N1; 2; villageois; .M.N1
# villageoisMDu; villageois; NOM; abito; ; abitol; abito-l; NOM, CF=N1,  Genre=M, Nombre=Du; villageois.M.N1-Du; 3; villageois; .M.N1; -Du
# villageoisMPl; villageois; NOM; abito; ; abitos; abito-s; NOM, CF=N1,  Genre=M, Nombre=Pl; villageois.M.N1-Pl; 3; villageois; .M.N1; -Pl
# combatMSg; combat; NOM; masakro; ; masakro; masakro; NOM, CF=N1,  Genre=M, Nombre=Sg; combat.M.N1; 2; combat; .M.N1
# combatMDu; combat; NOM; masakro; ; masakrol; masakro-l; NOM, CF=N1,  Genre=M, Nombre=Du; combat.M.N1-Du; 3; combat; .M.N1; -Du
# combatMPl; combat; NOM; masakro; ; masakros; masakro-s; NOM, CF=N1,  Genre=M, Nombre=Pl; combat.M.N1-Pl; 3; combat; .M.N1; -Pl
# hommeMSg; homme; NOM; mortemo; ; mortemo; mortemo; NOM, CF=N1,  Genre=M, Nombre=Sg; homme.M.N1; 2; homme; .M.N1
# hommeMDu; homme; NOM; mortemo; ; mortemol; mortemo-l; NOM, CF=N1,  Genre=M, Nombre=Du; homme.M.N1-Du; 3; homme; .M.N1; -Du
# hommeMPl; homme; NOM; mortemo; ; mortemos; mortemo-s; NOM, CF=N1,  Genre=M, Nombre=Pl; homme.M.N1-Pl; 3; homme; .M.N1; -Pl
# loupMSg; loup; NOM; garruo; ; garruo; garruo; NOM, CF=N1,  Genre=M, Nombre=Sg; loup.M.N1; 2; loup; .M.N1
# loupMDu; loup; NOM; garruo; ; garruol; garruo-l; NOM, CF=N1,  Genre=M, Nombre=Du; loup.M.N1-Du; 3; loup; .M.N1; -Du
# loupMPl; loup; NOM; garruo; ; garruos; garruo-s; NOM, CF=N1,  Genre=M, Nombre=Pl; loup.M.N1-Pl; 3; loup; .M.N1; -Pl
# KalebMSg; Kaleb; NOM; kalebe; ; kalebe; kalebe; NOM, CF=N2,  Genre=M, Nombre=Sg; Kaleb.M.N2; 2; Kaleb; .M.N2
# KalebMDu; Kaleb; NOM; kalebe; ; kalebel; kalebe-l; NOM, CF=N2,  Genre=M, Nombre=Du; Kaleb.M.N2-Du; 3; Kaleb; .M.N2; -Du
# KalebMPl; Kaleb; NOM; kalebe; ; kalebes; kalebe-s; NOM, CF=N2,  Genre=M, Nombre=Pl; Kaleb.M.N2-Pl; 3; Kaleb; .M.N2; -Pl
# souffranceMSg; souffrance; NOM; dollore; ; dollore; dollore; NOM, CF=N2,  Genre=M, Nombre=Sg; souffrance.M.N2; 2; souffrance; .M.N2
# souffranceMDu; souffrance; NOM; dollore; ; dollorel; dollore-l; NOM, CF=N2,  Genre=M, Nombre=Du; souffrance.M.N2-Du; 3; souffrance; .M.N2; -Du
# souffranceMPl; souffrance; NOM; dollore; ; dollores; dollore-s; NOM, CF=N2,  Genre=M, Nombre=Pl; souffrance.M.N2-Pl; 3; souffrance; .M.N2; -Pl
# couteauMSg; couteau; NOM; atame; ; atame; atame; NOM, CF=N2,  Genre=M, Nombre=Sg; couteau.M.N2; 2; couteau; .M.N2
# couteauMDu; couteau; NOM; atame; ; atamel; atame-l; NOM, CF=N2,  Genre=M, Nombre=Du; couteau.M.N2-Du; 3; couteau; .M.N2; -Du
# couteauMPl; couteau; NOM; atame; ; atames; atame-s; NOM, CF=N2,  Genre=M, Nombre=Pl; couteau.M.N2-Pl; 3; couteau; .M.N2; -Pl
# demonMSg; démon; NOM; ʃetane; ; ʃetane; ʃetane; NOM, CF=N2,  Genre=M, Nombre=Sg; démon.M.N2; 2; démon; .M.N2
# demonMDu; démon; NOM; ʃetane; ; ʃetanel; ʃetane-l; NOM, CF=N2,  Genre=M, Nombre=Du; démon.M.N2-Du; 3; démon; .M.N2; -Du
# demonMPl; démon; NOM; ʃetane; ; ʃetanes; ʃetane-s; NOM, CF=N2,  Genre=M, Nombre=Pl; démon.M.N2-Pl; 3; démon; .M.N2; -Pl
# enfantMSg; enfant; NOM; zenfane; ; zenfane; zenfane; NOM, CF=N2,  Genre=M, Nombre=Sg; enfant.hyper.M.N2; 2; enfant; .hyper.M.N2
# enfantMDu; enfant; NOM; zenfane; ; zenfanel; zenfane-l; NOM, CF=N2,  Genre=M, Nombre=Du; enfant.hyper.M.N2-Du; 3; enfant; .hyper.M.N2; -Du
# enfantMPl; enfant; NOM; zenfane; ; zenfanes; zenfane-s; NOM, CF=N2,  Genre=M, Nombre=Pl; enfant.hyper.M.N2-Pl; 3; enfant; .hyper.M.N2; -Pl
# chefMSg; chef; NOM; bwaje; ; bwaje; bwaje; NOM, CF=N2,  Genre=M, Nombre=Sg; chef.M.N2; 2; chef; .M.N2
# chefMDu; chef; NOM; bwaje; ; bwajel; bwaje-l; NOM, CF=N2,  Genre=M, Nombre=Du; chef.M.N2-Du; 3; chef; .M.N2; -Du
# chefMPl; chef; NOM; bwaje; ; bwajes; bwaje-s; NOM, CF=N2,  Genre=M, Nombre=Pl; chef.M.N2-Pl; 3; chef; .M.N2; -Pl
# gorgeMSg; gorge; NOM; traʃe; ; traʃe; traʃe; NOM, CF=N2,  Genre=M, Nombre=Sg; gorge.M.N2; 2; gorge; .M.N2
# gorgeMDu; gorge; NOM; traʃe; ; traʃel; traʃe-l; NOM, CF=N2,  Genre=M, Nombre=Du; gorge.M.N2-Du; 3; gorge; .M.N2; -Du
# gorgeMPl; gorge; NOM; traʃe; ; traʃes; traʃe-s; NOM, CF=N2,  Genre=M, Nombre=Pl; gorge.M.N2-Pl; 3; gorge; .M.N2; -Pl
# criMSg; cri; NOM; braje; ; braje; braje; NOM, CF=N2,  Genre=M, Nombre=Sg; cri.M.N2; 2; cri; .M.N2
# criMDu; cri; NOM; braje; ; brajel; braje-l; NOM, CF=N2,  Genre=M, Nombre=Du; cri.M.N2-Du; 3; cri; .M.N2; -Du
# criMPl; cri; NOM; braje; ; brajes; braje-s; NOM, CF=N2,  Genre=M, Nombre=Pl; cri.M.N2-Pl; 3; cri; .M.N2; -Pl
# milieuMSg; milieu; NOM; mwatje; ; mwatje; mwatje; NOM, CF=N2,  Genre=M, Nombre=Sg; milieu.M.N2; 2; milieu; .M.N2
# milieuMDu; milieu; NOM; mwatje; ; mwatjel; mwatje-l; NOM, CF=N2,  Genre=M, Nombre=Du; milieu.M.N2-Du; 3; milieu; .M.N2; -Du
# milieuMPl; milieu; NOM; mwatje; ; mwatjes; mwatje-s; NOM, CF=N2,  Genre=M, Nombre=Pl; milieu.M.N2-Pl; 3; milieu; .M.N2; -Pl
# arbreMSg; arbre; NOM; ʃenna; ; ʃenna; ʃenna; NOM, CF=N3,  Genre=M, Nombre=Sg; arbre.M.N3; 2; arbre; .M.N3
# arbreMDu; arbre; NOM; ʃenna; ; ʃennal; ʃenna-l; NOM, CF=N3,  Genre=M, Nombre=Du; arbre.M.N3-Du; 3; arbre; .M.N3; -Du
# arbreMPl; arbre; NOM; ʃenna; ; ʃennas; ʃenna-s; NOM, CF=N3,  Genre=M, Nombre=Pl; arbre.M.N3-Pl; 3; arbre; .M.N3; -Pl
# combattantMSg; combattant; NOM; ninʃa; ; ninʃa; ninʃa; NOM, CF=N3,  Genre=M, Nombre=Sg; combattant.M.N3; 2; combattant; .M.N3
# combattantMDu; combattant; NOM; ninʃa; ; ninʃal; ninʃa-l; NOM, CF=N3,  Genre=M, Nombre=Du; combattant.M.N3-Du; 3; combattant; .M.N3; -Du
# combattantMPl; combattant; NOM; ninʃa; ; ninʃas; ninʃa-s; NOM, CF=N3,  Genre=M, Nombre=Pl; combattant.M.N3-Pl; 3; combattant; .M.N3; -Pl
# serpentMSg; serpent; NOM; mamba; ; mamba; mamba; NOM, CF=N3,  Genre=M, Nombre=Sg; serpent.M.N3; 2; serpent; .M.N3
# serpentMDu; serpent; NOM; mamba; ; mambal; mamba-l; NOM, CF=N3,  Genre=M, Nombre=Du; serpent.M.N3-Du; 3; serpent; .M.N3; -Du
# serpentMPl; serpent; NOM; mamba; ; mambas; mamba-s; NOM, CF=N3,  Genre=M, Nombre=Pl; serpent.M.N3-Pl; 3; serpent; .M.N3; -Pl
# mainFSg; main; NOM; mimmina; ; mimmina; mimmina; NOM, CF=N1,  Genre=F, Nombre=Sg; main.F.N1; 2; main; .F.N1
# mainFDu; main; NOM; mimmina; ; mimminal; mimmina-l; NOM, CF=N1,  Genre=F, Nombre=Du; main.F.N1-Du; 3; main; .F.N1; -Du
# mainFPl; main; NOM; mimmina; ; mimminas; mimmina-s; NOM, CF=N1,  Genre=F, Nombre=Pl; main.F.N1-Pl; 3; main; .F.N1; -Pl
# filleFSg; fille; NOM; tʃika; ; tʃika; tʃika; NOM, CF=N1,  Genre=F, Nombre=Sg; fille.F.N1; 2; fille; .F.N1
# filleFDu; fille; NOM; tʃika; ; tʃikal; tʃika-l; NOM, CF=N1,  Genre=F, Nombre=Du; fille.F.N1-Du; 3; fille; .F.N1; -Du
# filleFPl; fille; NOM; tʃika; ; tʃikas; tʃika-s; NOM, CF=N1,  Genre=F, Nombre=Pl; fille.F.N1-Pl; 3; fille; .F.N1; -Pl
# colereFSg; colère; NOM; raʒa; ; raʒa; raʒa; NOM, CF=N1,  Genre=F, Nombre=Sg; colère.F.N1; 2; colère; .F.N1
# colereFDu; colère; NOM; raʒa; ; raʒal; raʒa-l; NOM, CF=N1,  Genre=F, Nombre=Du; colère.F.N1-Du; 3; colère; .F.N1; -Du
# colereFPl; colère; NOM; raʒa; ; raʒas; raʒa-s; NOM, CF=N1,  Genre=F, Nombre=Pl; colère.F.N1-Pl; 3; colère; .F.N1; -Pl
# nuitFSg; nuit; NOM; noksa; ; noksa; noksa; NOM, CF=N1,  Genre=F, Nombre=Sg; nuit.F.N1; 2; nuit; .F.N1
# nuitFDu; nuit; NOM; noksa; ; noksal; noksa-l; NOM, CF=N1,  Genre=F, Nombre=Du; nuit.F.N1-Du; 3; nuit; .F.N1; -Du
# nuitFPl; nuit; NOM; noksa; ; noksas; noksa-s; NOM, CF=N1,  Genre=F, Nombre=Pl; nuit.F.N1-Pl; 3; nuit; .F.N1; -Pl
# ombreFSg; ombre; NOM; menasa; ; menasa; menasa; NOM, CF=N1,  Genre=F, Nombre=Sg; ombre.F.N1; 2; ombre; .F.N1
# ombreFDu; ombre; NOM; menasa; ; menasal; menasa-l; NOM, CF=N1,  Genre=F, Nombre=Du; ombre.F.N1-Du; 3; ombre; .F.N1; -Du
# ombreFPl; ombre; NOM; menasa; ; menasas; menasa-s; NOM, CF=N1,  Genre=F, Nombre=Pl; ombre.F.N1-Pl; 3; ombre; .F.N1; -Pl
# maisonFSg; maison; NOM; jurta; ; jurta; jurta; NOM, CF=N1,  Genre=F, Nombre=Sg; maison.F.N1; 2; maison; .F.N1
# maisonFDu; maison; NOM; jurta; ; jurtal; jurta-l; NOM, CF=N1,  Genre=F, Nombre=Du; maison.F.N1-Du; 3; maison; .F.N1; -Du
# maisonFPl; maison; NOM; jurta; ; jurtas; jurta-s; NOM, CF=N1,  Genre=F, Nombre=Pl; maison.F.N1-Pl; 3; maison; .F.N1; -Pl
# VioletteFSg; Violette; NOM; vjoleta; ; vjoleta; vjoleta; NOM, CF=N1,  Genre=F, Nombre=Sg; Violette.F.N1; 2; Violette; .F.N1
# VioletteFDu; Violette; NOM; vjoleta; ; vjoletal; vjoleta-l; NOM, CF=N1,  Genre=F, Nombre=Du; Violette.F.N1-Du; 3; Violette; .F.N1; -Du
# VioletteFPl; Violette; NOM; vjoleta; ; vjoletas; vjoleta-s; NOM, CF=N1,  Genre=F, Nombre=Pl; Violette.F.N1-Pl; 3; Violette; .F.N1; -Pl
# MahiraFSg; Mahira; NOM; maira; ; maira; maira; NOM, CF=N1,  Genre=F, Nombre=Sg; Mahira.F.N1; 2; Mahira; .F.N1
# MahiraFDu; Mahira; NOM; maira; ; mairal; maira-l; NOM, CF=N1,  Genre=F, Nombre=Du; Mahira.F.N1-Du; 3; Mahira; .F.N1; -Du
# MahiraFPl; Mahira; NOM; maira; ; mairas; maira-s; NOM, CF=N1,  Genre=F, Nombre=Pl; Mahira.F.N1-Pl; 3; Mahira; .F.N1; -Pl
# enfantFSg; enfant; NOM; zanfana; ; zanfana; zanfana; NOM, CF=N1,  Genre=F, Nombre=Sg; enfant.F.N1; 2; enfant; .F.N1
# enfantFDu; enfant; NOM; zanfana; ; zanfanal; zanfana-l; NOM, CF=N1,  Genre=F, Nombre=Du; enfant.F.N1-Du; 3; enfant; .F.N1; -Du
# enfantFPl; enfant; NOM; zanfana; ; zanfanas; zanfana-s; NOM, CF=N1,  Genre=F, Nombre=Pl; enfant.F.N1-Pl; 3; enfant; .F.N1; -Pl
# luneFSg; lune; NOM; astra; ; astra; astra; NOM, CF=N1,  Genre=F, Nombre=Sg; lune.F.N1; 2; lune; .F.N1
# luneFDu; lune; NOM; astra; ; astral; astra-l; NOM, CF=N1,  Genre=F, Nombre=Du; lune.F.N1-Du; 3; lune; .F.N1; -Du
# luneFPl; lune; NOM; astra; ; astras; astra-s; NOM, CF=N1,  Genre=F, Nombre=Pl; lune.F.N1-Pl; 3; lune; .F.N1; -Pl
# louveFSg; louve; NOM; garuva; ; garuva; garuva; NOM, CF=N1,  Genre=F, Nombre=Sg; louve.F.N1; 2; louve; .F.N1
# louveFDu; louve; NOM; garuva; ; garuval; garuva-l; NOM, CF=N1,  Genre=F, Nombre=Du; louve.F.N1-Du; 3; louve; .F.N1; -Du
# louveFPl; louve; NOM; garuva; ; garuvas; garuva-s; NOM, CF=N1,  Genre=F, Nombre=Pl; louve.F.N1-Pl; 3; louve; .F.N1; -Pl
# crocFSg; croc; NOM; kajnina; ; kajnina; kajnina; NOM, CF=N1,  Genre=F, Nombre=Sg; croc.F.N1; 2; croc; .F.N1
# crocFDu; croc; NOM; kajnina; ; kajninal; kajnina-l; NOM, CF=N1,  Genre=F, Nombre=Du; croc.F.N1-Du; 3; croc; .F.N1; -Du
# crocFPl; croc; NOM; kajnina; ; kajninas; kajnina-s; NOM, CF=N1,  Genre=F, Nombre=Pl; croc.F.N1-Pl; 3; croc; .F.N1; -Pl
# lanceFSg; lance; NOM; piloma; ; piloma; piloma; NOM, CF=N1,  Genre=F, Nombre=Sg; lance.F.N1; 2; lance; .F.N1
# lanceFDu; lance; NOM; piloma; ; pilomal; piloma-l; NOM, CF=N1,  Genre=F, Nombre=Du; lance.F.N1-Du; 3; lance; .F.N1; -Du
# lanceFPl; lance; NOM; piloma; ; pilomas; piloma-s; NOM, CF=N1,  Genre=F, Nombre=Pl; lance.F.N1-Pl; 3; lance; .F.N1; -Pl
# soeurFSg; soeur; NOM; sestra; ; sestra; sestra; NOM, CF=N1,  Genre=F, Nombre=Sg; soeur.F.N1; 2; soeur; .F.N1
# soeurFDu; soeur; NOM; sestra; ; sestral; sestra-l; NOM, CF=N1,  Genre=F, Nombre=Du; soeur.F.N1-Du; 3; soeur; .F.N1; -Du
# soeurFPl; soeur; NOM; sestra; ; sestras; sestra-s; NOM, CF=N1,  Genre=F, Nombre=Pl; soeur.F.N1-Pl; 3; soeur; .F.N1; -Pl
# villageoiseFSg; villageoise; NOM; abita; ; abita; abita; NOM, CF=N1,  Genre=F, Nombre=Sg; villageoise.F.N1; 2; villageoise; .F.N1
# villageoiseFDu; villageoise; NOM; abita; ; abital; abita-l; NOM, CF=N1,  Genre=F, Nombre=Du; villageoise.F.N1-Du; 3; villageoise; .F.N1; -Du
# villageoiseFPl; villageoise; NOM; abita; ; abitas; abita-s; NOM, CF=N1,  Genre=F, Nombre=Pl; villageoise.F.N1-Pl; 3; villageoise; .F.N1; -Pl
# mortFSg; mort; NOM; klamse; ; klamse; klamse; NOM, CF=N2,  Genre=F, Nombre=Sg; mort.F.N2; 2; mort; .F.N2
# mortFDu; mort; NOM; klamse; ; klamsel; klamse-l; NOM, CF=N2,  Genre=F, Nombre=Du; mort.F.N2-Du; 3; mort; .F.N2; -Du
# mortFPl; mort; NOM; klamse; ; klamses; klamse-s; NOM, CF=N2,  Genre=F, Nombre=Pl; mort.F.N2-Pl; 3; mort; .F.N2; -Pl
# blessureFSg; blessure; NOM; grife; ; grife; grife; NOM, CF=N2,  Genre=F, Nombre=Sg; blessure.F.N2; 2; blessure; .F.N2
# blessureFDu; blessure; NOM; grife; ; grifel; grife-l; NOM, CF=N2,  Genre=F, Nombre=Du; blessure.F.N2-Du; 3; blessure; .F.N2; -Du
# blessureFPl; blessure; NOM; grife; ; grifes; grife-s; NOM, CF=N2,  Genre=F, Nombre=Pl; blessure.F.N2-Pl; 3; blessure; .F.N2; -Pl
# foretFSg; forêt; NOM; boske; ; boske; boske; NOM, CF=N2,  Genre=F, Nombre=Sg; forêt.F.N2; 2; forêt; .F.N2
# foretFDu; forêt; NOM; boske; ; boskel; boske-l; NOM, CF=N2,  Genre=F, Nombre=Du; forêt.F.N2-Du; 3; forêt; .F.N2; -Du
# foretFPl; forêt; NOM; boske; ; boskes; boske-s; NOM, CF=N2,  Genre=F, Nombre=Pl; forêt.F.N2-Pl; 3; forêt; .F.N2; -Pl
# lueurFSg; lueur; NOM; allo; ; allo; allo; NOM, CF=N3,  Genre=F, Nombre=Sg; lueur.F.N3; 2; lueur; .F.N3
# lueurFDu; lueur; NOM; allo; ; allol; allo-l; NOM, CF=N3,  Genre=F, Nombre=Du; lueur.F.N3-Du; 3; lueur; .F.N3; -Du
# lueurFPl; lueur; NOM; allo; ; allos; allo-s; NOM, CF=N3,  Genre=F, Nombre=Pl; lueur.F.N3-Pl; 3; lueur; .F.N3; -Pl
# INDMSg; IND; DET; un; ; uno; un-o; DET, Genre=M, Nombre=Sg; IND-M; 2; IND; -M
# INDMDu; IND; DET; un; ; unol; un-o-l; DET, Genre=M, Nombre=Du; IND-M-Du; 3; IND; -M; -Du
# INDMPl; IND; DET; un; ; unos; un-o-s; DET, Genre=M, Nombre=Pl; IND-M-Pl; 3; IND; -M; -Pl
# INDFSg; IND; DET; un; ; una; un-a; DET, Genre=F, Nombre=Sg; IND-F; 2; IND; -F
# INDFDu; IND; DET; un; ; unal; un-a-l; DET, Genre=F, Nombre=Du; IND-F-Du; 3; IND; -F; -Du
# INDFPl; IND; DET; un; ; unas; un-a-s; DET, Genre=F, Nombre=Pl; IND-F-Pl; 3; IND; -F; -Pl
# DEFMSg; DEF; DET; l; ; lo; l-o; DET, Genre=M, Nombre=Sg; DEF-M; 2; DEF; -M
# DEFMDu; DEF; DET; l; ; lol; l-o-l; DET, Genre=M, Nombre=Du; DEF-M-Du; 3; DEF; -M; -Du
# DEFMPl; DEF; DET; l; ; los; l-o-s; DET, Genre=M, Nombre=Pl; DEF-M-Pl; 3; DEF; -M; -Pl
# DEFFSg; DEF; DET; l; ; la; l-a; DET, Genre=F, Nombre=Sg; DEF-F; 2; DEF; -F
# DEFFDu; DEF; DET; l; ; lal; l-a-l; DET, Genre=F, Nombre=Du; DEF-F-Du; 3; DEF; -F; -Du
# DEFFPl; DEF; DET; l; ; las; l-a-s; DET, Genre=F, Nombre=Pl; DEF-F-Pl; 3; DEF; -F; -Pl
# DEMMSg; DEM; DET; st; ; sto; st-o; DET, Genre=M, Nombre=Sg; DEM-M; 2; DEM; -M
# DEMMDu; DEM; DET; st; ; stol; st-o-l; DET, Genre=M, Nombre=Du; DEM-M-Du; 3; DEM; -M; -Du
# DEMMPl; DEM; DET; st; ; stos; st-o-s; DET, Genre=M, Nombre=Pl; DEM-M-Pl; 3; DEM; -M; -Pl
# DEMFSg; DEM; DET; st; ; sta; st-a; DET, Genre=F, Nombre=Sg; DEM-F; 2; DEM; -F
# DEMFDu; DEM; DET; st; ; stal; st-a-l; DET, Genre=F, Nombre=Du; DEM-F-Du; 3; DEM; -F; -Du
# DEMFPl; DEM; DET; st; ; stas; st-a-s; DET, Genre=F, Nombre=Pl; DEM-F-Pl; 3; DEM; -F; -Pl
# profondMSg; profond; ADJ; krevas; ; krevaso; krevas-o; ADJ, Genre=M, Nombre=Sg; profond-M; 2; profond; -M
# profondMDu; profond; ADJ; krevas; ; krevasol; krevas-o-l; ADJ, Genre=M, Nombre=Du; profond-M-Du; 3; profond; -M; -Du
# profondMPl; profond; ADJ; krevas; ; krevasos; krevas-o-s; ADJ, Genre=M, Nombre=Pl; profond-M-Pl; 3; profond; -M; -Pl
# profondFSg; profond; ADJ; krevas; ; krevasa; krevas-a; ADJ, Genre=F, Nombre=Sg; profond-F; 2; profond; -F
# profondFDu; profond; ADJ; krevas; ; krevasal; krevas-a-l; ADJ, Genre=F, Nombre=Du; profond-F-Du; 3; profond; -F; -Du
# profondFPl; profond; ADJ; krevas; ; krevasas; krevas-a-s; ADJ, Genre=F, Nombre=Pl; profond-F-Pl; 3; profond; -F; -Pl
# rougeMSg; rouge; ADJ; pastek; ; pasteko; pastek-o; ADJ, Genre=M, Nombre=Sg; rouge-M; 2; rouge; -M
# rougeMDu; rouge; ADJ; pastek; ; pastekol; pastek-o-l; ADJ, Genre=M, Nombre=Du; rouge-M-Du; 3; rouge; -M; -Du
# rougeMPl; rouge; ADJ; pastek; ; pastekos; pastek-o-s; ADJ, Genre=M, Nombre=Pl; rouge-M-Pl; 3; rouge; -M; -Pl
# rougeFSg; rouge; ADJ; pastek; ; pasteka; pastek-a; ADJ, Genre=F, Nombre=Sg; rouge-F; 2; rouge; -F
# rougeFDu; rouge; ADJ; pastek; ; pastekal; pastek-a-l; ADJ, Genre=F, Nombre=Du; rouge-F-Du; 3; rouge; -F; -Du
# rougeFPl; rouge; ADJ; pastek; ; pastekas; pastek-a-s; ADJ, Genre=F, Nombre=Pl; rouge-F-Pl; 3; rouge; -F; -Pl
# effrayeMSg; effrayé; ADJ; turmant; ; turmanto; turmant-o; ADJ, Genre=M, Nombre=Sg; effrayé-M; 2; effrayé; -M
# effrayeMDu; effrayé; ADJ; turmant; ; turmantol; turmant-o-l; ADJ, Genre=M, Nombre=Du; effrayé-M-Du; 3; effrayé; -M; -Du
# effrayeMPl; effrayé; ADJ; turmant; ; turmantos; turmant-o-s; ADJ, Genre=M, Nombre=Pl; effrayé-M-Pl; 3; effrayé; -M; -Pl
# effrayeFSg; effrayé; ADJ; turmant; ; turmanta; turmant-a; ADJ, Genre=F, Nombre=Sg; effrayé-F; 2; effrayé; -F
# effrayeFDu; effrayé; ADJ; turmant; ; turmantal; turmant-a-l; ADJ, Genre=F, Nombre=Du; effrayé-F-Du; 3; effrayé; -F; -Du
# effrayeFPl; effrayé; ADJ; turmant; ; turmantas; turmant-a-s; ADJ, Genre=F, Nombre=Pl; effrayé-F-Pl; 3; effrayé; -F; -Pl
# terribleMSg; terrible; ADJ; atros; ; atroso; atros-o; ADJ, Genre=M, Nombre=Sg; terrible-M; 2; terrible; -M
# terribleMDu; terrible; ADJ; atros; ; atrosol; atros-o-l; ADJ, Genre=M, Nombre=Du; terrible-M-Du; 3; terrible; -M; -Du
# terribleMPl; terrible; ADJ; atros; ; atrosos; atros-o-s; ADJ, Genre=M, Nombre=Pl; terrible-M-Pl; 3; terrible; -M; -Pl
# terribleFSg; terrible; ADJ; atros; ; atrosa; atros-a; ADJ, Genre=F, Nombre=Sg; terrible-F; 2; terrible; -F
# terribleFDu; terrible; ADJ; atros; ; atrosal; atros-a-l; ADJ, Genre=F, Nombre=Du; terrible-F-Du; 3; terrible; -F; -Du
# terribleFPl; terrible; ADJ; atros; ; atrosas; atros-a-s; ADJ, Genre=F, Nombre=Pl; terrible-F-Pl; 3; terrible; -F; -Pl
# furieuxMSg; furieux; ADJ; raʒ; ; raʒo; raʒ-o; ADJ, Genre=M, Nombre=Sg; furieux-M; 2; furieux; -M
# furieuxMDu; furieux; ADJ; raʒ; ; raʒol; raʒ-o-l; ADJ, Genre=M, Nombre=Du; furieux-M-Du; 3; furieux; -M; -Du
# furieuxMPl; furieux; ADJ; raʒ; ; raʒos; raʒ-o-s; ADJ, Genre=M, Nombre=Pl; furieux-M-Pl; 3; furieux; -M; -Pl
# furieuxFSg; furieux; ADJ; raʒ; ; raʒa; raʒ-a; ADJ, Genre=F, Nombre=Sg; furieux-F; 2; furieux; -F
# furieuxFDu; furieux; ADJ; raʒ; ; raʒal; raʒ-a-l; ADJ, Genre=F, Nombre=Du; furieux-F-Du; 3; furieux; -F; -Du
# furieuxFPl; furieux; ADJ; raʒ; ; raʒas; raʒ-a-s; ADJ, Genre=F, Nombre=Pl; furieux-F-Pl; 3; furieux; -F; -Pl
# blancMSg; blanc; ADJ; neʒ; ; neʒo; neʒ-o; ADJ, Genre=M, Nombre=Sg; blanc-M; 2; blanc; -M
# blancMDu; blanc; ADJ; neʒ; ; neʒol; neʒ-o-l; ADJ, Genre=M, Nombre=Du; blanc-M-Du; 3; blanc; -M; -Du
# blancMPl; blanc; ADJ; neʒ; ; neʒos; neʒ-o-s; ADJ, Genre=M, Nombre=Pl; blanc-M-Pl; 3; blanc; -M; -Pl
# blancFSg; blanc; ADJ; neʒ; ; neʒa; neʒ-a; ADJ, Genre=F, Nombre=Sg; blanc-F; 2; blanc; -F
# blancFDu; blanc; ADJ; neʒ; ; neʒal; neʒ-a-l; ADJ, Genre=F, Nombre=Du; blanc-F-Du; 3; blanc; -F; -Du
# blancFPl; blanc; ADJ; neʒ; ; neʒas; neʒ-a-s; ADJ, Genre=F, Nombre=Pl; blanc-F-Pl; 3; blanc; -F; -Pl
# grandMSg; grand; ADJ; makros; ; makroso; makros-o; ADJ, Genre=M, Nombre=Sg; grand-M; 2; grand; -M
# grandMDu; grand; ADJ; makros; ; makrosol; makros-o-l; ADJ, Genre=M, Nombre=Du; grand-M-Du; 3; grand; -M; -Du
# grandMPl; grand; ADJ; makros; ; makrosos; makros-o-s; ADJ, Genre=M, Nombre=Pl; grand-M-Pl; 3; grand; -M; -Pl
# grandFSg; grand; ADJ; makros; ; makrosa; makros-a; ADJ, Genre=F, Nombre=Sg; grand-F; 2; grand; -F
# grandFDu; grand; ADJ; makros; ; makrosal; makros-a-l; ADJ, Genre=F, Nombre=Du; grand-F-Du; 3; grand; -F; -Du
# grandFPl; grand; ADJ; makros; ; makrosas; makros-a-s; ADJ, Genre=F, Nombre=Pl; grand-F-Pl; 3; grand; -F; -Pl
# differentMSg; différent; ADJ; otr; ; otro; otr-o; ADJ, Genre=M, Nombre=Sg; différent-M; 2; différent; -M
# differentMDu; différent; ADJ; otr; ; otrol; otr-o-l; ADJ, Genre=M, Nombre=Du; différent-M-Du; 3; différent; -M; -Du
# differentMPl; différent; ADJ; otr; ; otros; otr-o-s; ADJ, Genre=M, Nombre=Pl; différent-M-Pl; 3; différent; -M; -Pl
# differentFSg; différent; ADJ; otr; ; otra; otr-a; ADJ, Genre=F, Nombre=Sg; différent-F; 2; différent; -F
# differentFDu; différent; ADJ; otr; ; otral; otr-a-l; ADJ, Genre=F, Nombre=Du; différent-F-Du; 3; différent; -F; -Du
# differentFPl; différent; ADJ; otr; ; otras; otr-a-s; ADJ, Genre=F, Nombre=Pl; différent-F-Pl; 3; différent; -F; -Pl
# suivantMSg; suivant; ADJ; proʃen; ; proʃeno; proʃen-o; ADJ, Genre=M, Nombre=Sg; suivant-M; 2; suivant; -M
# suivantMDu; suivant; ADJ; proʃen; ; proʃenol; proʃen-o-l; ADJ, Genre=M, Nombre=Du; suivant-M-Du; 3; suivant; -M; -Du
# suivantMPl; suivant; ADJ; proʃen; ; proʃenos; proʃen-o-s; ADJ, Genre=M, Nombre=Pl; suivant-M-Pl; 3; suivant; -M; -Pl
# suivantFSg; suivant; ADJ; proʃen; ; proʃena; proʃen-a; ADJ, Genre=F, Nombre=Sg; suivant-F; 2; suivant; -F
# suivantFDu; suivant; ADJ; proʃen; ; proʃenal; proʃen-a-l; ADJ, Genre=F, Nombre=Du; suivant-F-Du; 3; suivant; -F; -Du
# suivantFPl; suivant; ADJ; proʃen; ; proʃenas; proʃen-a-s; ADJ, Genre=F, Nombre=Pl; suivant-F-Pl; 3; suivant; -F; -Pl
# petitMSg; petit; ADJ; mikron; ; mikrono; mikron-o; ADJ, Genre=M, Nombre=Sg; petit-M; 2; petit; -M
# petitMDu; petit; ADJ; mikron; ; mikronol; mikron-o-l; ADJ, Genre=M, Nombre=Du; petit-M-Du; 3; petit; -M; -Du
# petitMPl; petit; ADJ; mikron; ; mikronos; mikron-o-s; ADJ, Genre=M, Nombre=Pl; petit-M-Pl; 3; petit; -M; -Pl
# petitFSg; petit; ADJ; mikron; ; mikrona; mikron-a; ADJ, Genre=F, Nombre=Sg; petit-F; 2; petit; -F
# petitFDu; petit; ADJ; mikron; ; mikronal; mikron-a-l; ADJ, Genre=F, Nombre=Du; petit-F-Du; 3; petit; -F; -Du
# petitFPl; petit; ADJ; mikron; ; mikronas; mikron-a-s; ADJ, Genre=F, Nombre=Pl; petit-F-Pl; 3; petit; -F; -Pl
# blesseMSg; blessé; ADJ; estrop; ; estropo; estrop-o; ADJ, Genre=M, Nombre=Sg; blessé-M; 2; blessé; -M
# blesseMDu; blessé; ADJ; estrop; ; estropol; estrop-o-l; ADJ, Genre=M, Nombre=Du; blessé-M-Du; 3; blessé; -M; -Du
# blesseMPl; blessé; ADJ; estrop; ; estropos; estrop-o-s; ADJ, Genre=M, Nombre=Pl; blessé-M-Pl; 3; blessé; -M; -Pl
# blesseFSg; blessé; ADJ; estrop; ; estropa; estrop-a; ADJ, Genre=F, Nombre=Sg; blessé-F; 2; blessé; -F
# blesseFDu; blessé; ADJ; estrop; ; estropal; estrop-a-l; ADJ, Genre=F, Nombre=Du; blessé-F-Du; 3; blessé; -F; -Du
# blesseFPl; blessé; ADJ; estrop; ; estropas; estrop-a-s; ADJ, Genre=F, Nombre=Pl; blessé-F-Pl; 3; blessé; -F; -Pl
# noirMSg; noir; ADJ; lamer; ; lamero; lamer-o; ADJ, Genre=M, Nombre=Sg; noir-M; 2; noir; -M
# noirMDu; noir; ADJ; lamer; ; lamerol; lamer-o-l; ADJ, Genre=M, Nombre=Du; noir-M-Du; 3; noir; -M; -Du
# noirMPl; noir; ADJ; lamer; ; lameros; lamer-o-s; ADJ, Genre=M, Nombre=Pl; noir-M-Pl; 3; noir; -M; -Pl
# noirFSg; noir; ADJ; lamer; ; lamera; lamer-a; ADJ, Genre=F, Nombre=Sg; noir-F; 2; noir; -F
# noirFDu; noir; ADJ; lamer; ; lameral; lamer-a-l; ADJ, Genre=F, Nombre=Du; noir-F-Du; 3; noir; -F; -Du
# noirFPl; noir; ADJ; lamer; ; lameras; lamer-a-s; ADJ, Genre=F, Nombre=Pl; noir-F-Pl; 3; noir; -F; -Pl
# courageuxMSg; courageux; ADJ; brav; ; bravo; brav-o; ADJ, Genre=M, Nombre=Sg; courageux-M; 2; courageux; -M
# courageuxMDu; courageux; ADJ; brav; ; bravol; brav-o-l; ADJ, Genre=M, Nombre=Du; courageux-M-Du; 3; courageux; -M; -Du
# courageuxMPl; courageux; ADJ; brav; ; bravos; brav-o-s; ADJ, Genre=M, Nombre=Pl; courageux-M-Pl; 3; courageux; -M; -Pl
# courageuxFSg; courageux; ADJ; brav; ; brava; brav-a; ADJ, Genre=F, Nombre=Sg; courageux-F; 2; courageux; -F
# courageuxFDu; courageux; ADJ; brav; ; braval; brav-a-l; ADJ, Genre=F, Nombre=Du; courageux-F-Du; 3; courageux; -F; -Du
# courageuxFPl; courageux; ADJ; brav; ; bravas; brav-a-s; ADJ, Genre=F, Nombre=Pl; courageux-F-Pl; 3; courageux; -F; -Pl
# DEVANT; DEVANT; PREP; nen; ; nen; nen; PREP; devant; 1; devant
# DE; DE; PREP; ad; ; ad; ad; PREP; de; 1; de
# ENTRE; ENTRE; PREP; ron; ; ron; ron; PREP; ENTRE; 1; ENTRE
# ...
# nuitFPl; nuit; NOM; noksa; ; noksas; noksa-s; NOM, CF=N1,  Genre=F, Nombre=Pl; nuit.F.N1-Pl; 3; nuit; .F.N1; -Pl
# ombreFSg; ombre; NOM; menasa; ; menasa; menasa; NOM, CF=N1,  Genre=F, Nombre=Sg; ombre.F.N1; 2; ombre; .F.N1
# ombreFDu; ombre; NOM; menasa; ; menasal; menasa-l; NOM, CF=N1,  Genre=F, Nombre=Du; ombre.F.N1-Du; 3; ombre; .F.N1; -Du
# ombreFPl; ombre; NOM; menasa; ; menasas; menasa-s; NOM, CF=N1,  Genre=F, Nombre=Pl; ombre.F.N1-Pl; 3; ombre; .F.N1; -Pl
# maisonFSg; maison; NOM; jurta; ; jurta; jurta; NOM, CF=N1,  Genre=F, Nombre=Sg; maison.F.N1; 2; maison; .F.N1
# maisonFDu; maison; NOM; jurta; ; jurtal; jurta-l; NOM, CF=N1,  Genre=F, Nombre=Du; maison.F.N1-Du; 3; maison; .F.N1; -Du
# maisonFPl; maison; NOM; jurta; ; jurtas; jurta-s; NOM, CF=N1,  Genre=F, Nombre=Pl; maison.F.N1-Pl; 3; maison; .F.N1; -Pl
# VioletteFSg; Violette; NOM; vjoleta; ; vjoleta; vjoleta; NOM, CF=N1,  Genre=F, Nombre=Sg; Violette.F.N1; 2; Violette; .F.N1
# VioletteFDu; Violette; NOM; vjoleta; ; vjoletal; vjoleta-l; NOM, CF=N1,  Genre=F, Nombre=Du; Violette.F.N1-Du; 3; Violette; .F.N1; -Du
# VioletteFPl; Violette; NOM; vjoleta; ; vjoletas; vjoleta-s; NOM, CF=N1,  Genre=F, Nombre=Pl; Violette.F.N1-Pl; 3; Violette; .F.N1; -Pl
# MahiraFSg; Mahira; NOM; maira; ; maira; maira; NOM, CF=N1,  Genre=F, Nombre=Sg; Mahira.F.N1; 2; Mahira; .F.N1
# MahiraFDu; Mahira; NOM; maira; ; mairal; maira-l; NOM, CF=N1,  Genre=F, Nombre=Du; Mahira.F.N1-Du; 3; Mahira; .F.N1; -Du
# MahiraFPl; Mahira; NOM; maira; ; mairas; maira-s; NOM, CF=N1,  Genre=F, Nombre=Pl; Mahira.F.N1-Pl; 3; Mahira; .F.N1; -Pl
# enfantFSg; enfant; NOM; zanfana; ; zanfana; zanfana; NOM, CF=N1,  Genre=F, Nombre=Sg; enfant.F.N1; 2; enfant; .F.N1
# enfantFDu; enfant; NOM; zanfana; ; zanfanal; zanfana-l; NOM, CF=N1,  Genre=F, Nombre=Du; enfant.F.N1-Du; 3; enfant; .F.N1; -Du
# enfantFPl; enfant; NOM; zanfana; ; zanfanas; zanfana-s; NOM, CF=N1,  Genre=F, Nombre=Pl; enfant.F.N1-Pl; 3; enfant; .F.N1; -Pl
# luneFSg; lune; NOM; astra; ; astra; astra; NOM, CF=N1,  Genre=F, Nombre=Sg; lune.F.N1; 2; lune; .F.N1
# luneFDu; lune; NOM; astra; ; astral; astra-l; NOM, CF=N1,  Genre=F, Nombre=Du; lune.F.N1-Du; 3; lune; .F.N1; -Du
# luneFPl; lune; NOM; astra; ; astras; astra-s; NOM, CF=N1,  Genre=F, Nombre=Pl; lune.F.N1-Pl; 3; lune; .F.N1; -Pl
# louveFSg; louve; NOM; garuva; ; garuva; garuva; NOM, CF=N1,  Genre=F, Nombre=Sg; louve.F.N1; 2; louve; .F.N1
# louveFDu; louve; NOM; garuva; ; garuval; garuva-l; NOM, CF=N1,  Genre=F, Nombre=Du; louve.F.N1-Du; 3; louve; .F.N1; -Du
# louveFPl; louve; NOM; garuva; ; garuvas; garuva-s; NOM, CF=N1,  Genre=F, Nombre=Pl; louve.F.N1-Pl; 3; louve; .F.N1; -Pl
# crocFSg; croc; NOM; kajnina; ; kajnina; kajnina; NOM, CF=N1,  Genre=F, Nombre=Sg; croc.F.N1; 2; croc; .F.N1
# crocFDu; croc; NOM; kajnina; ; kajninal; kajnina-l; NOM, CF=N1,  Genre=F, Nombre=Du; croc.F.N1-Du; 3; croc; .F.N1; -Du
# crocFPl; croc; NOM; kajnina; ; kajninas; kajnina-s; NOM, CF=N1,  Genre=F, Nombre=Pl; croc.F.N1-Pl; 3; croc; .F.N1; -Pl
# lanceFSg; lance; NOM; piloma; ; piloma; piloma; NOM, CF=N1,  Genre=F, Nombre=Sg; lance.F.N1; 2; lance; .F.N1
# lanceFDu; lance; NOM; piloma; ; pilomal; piloma-l; NOM, CF=N1,  Genre=F, Nombre=Du; lance.F.N1-Du; 3; lance; .F.N1; -Du
# lanceFPl; lance; NOM; piloma; ; pilomas; piloma-s; NOM, CF=N1,  Genre=F, Nombre=Pl; lance.F.N1-Pl; 3; lance; .F.N1; -Pl
# soeurFSg; soeur; NOM; sestra; ; sestra; sestra; NOM, CF=N1,  Genre=F, Nombre=Sg; soeur.F.N1; 2; soeur; .F.N1
# soeurFDu; soeur; NOM; sestra; ; sestral; sestra-l; NOM, CF=N1,  Genre=F, Nombre=Du; soeur.F.N1-Du; 3; soeur; .F.N1; -Du
# soeurFPl; soeur; NOM; sestra; ; sestras; sestra-s; NOM, CF=N1,  Genre=F, Nombre=Pl; soeur.F.N1-Pl; 3; soeur; .F.N1; -Pl
# villageoiseFSg; villageoise; NOM; abita; ; abita; abita; NOM, CF=N1,  Genre=F, Nombre=Sg; villageoise.F.N1; 2; villageoise; .F.N1
# villageoiseFDu; villageoise; NOM; abita; ; abital; abita-l; NOM, CF=N1,  Genre=F, Nombre=Du; villageoise.F.N1-Du; 3; villageoise; .F.N1; -Du
# villageoiseFPl; villageoise; NOM; abita; ; abitas; abita-s; NOM, CF=N1,  Genre=F, Nombre=Pl; villageoise.F.N1-Pl; 3; villageoise; .F.N1; -Pl
# mortFSg; mort; NOM; klamse; ; klamse; klamse; NOM, CF=N2,  Genre=F, Nombre=Sg; mort.F.N2; 2; mort; .F.N2
# mortFDu; mort; NOM; klamse; ; klamsel; klamse-l; NOM, CF=N2,  Genre=F, Nombre=Du; mort.F.N2-Du; 3; mort; .F.N2; -Du
# mortFPl; mort; NOM; klamse; ; klamses; klamse-s; NOM, CF=N2,  Genre=F, Nombre=Pl; mort.F.N2-Pl; 3; mort; .F.N2; -Pl
# blessureFSg; blessure; NOM; grife; ; grife; grife; NOM, CF=N2,  Genre=F, Nombre=Sg; blessure.F.N2; 2; blessure; .F.N2
# blessureFDu; blessure; NOM; grife; ; grifel; grife-l; NOM, CF=N2,  Genre=F, Nombre=Du; blessure.F.N2-Du; 3; blessure; .F.N2; -Du
# blessureFPl; blessure; NOM; grife; ; grifes; grife-s; NOM, CF=N2,  Genre=F, Nombre=Pl; blessure.F.N2-Pl; 3; blessure; .F.N2; -Pl
# foretFSg; forêt; NOM; boske; ; boske; boske; NOM, CF=N2,  Genre=F, Nombre=Sg; forêt.F.N2; 2; forêt; .F.N2
# foretFDu; forêt; NOM; boske; ; boskel; boske-l; NOM, CF=N2,  Genre=F, Nombre=Du; forêt.F.N2-Du; 3; forêt; .F.N2; -Du
# foretFPl; forêt; NOM; boske; ; boskes; boske-s; NOM, CF=N2,  Genre=F, Nombre=Pl; forêt.F.N2-Pl; 3; forêt; .F.N2; -Pl
# lueurFSg; lueur; NOM; allo; ; allo; allo; NOM, CF=N3,  Genre=F, Nombre=Sg; lueur.F.N3; 2; lueur; .F.N3
# lueurFDu; lueur; NOM; allo; ; allol; allo-l; NOM, CF=N3,  Genre=F, Nombre=Du; lueur.F.N3-Du; 3; lueur; .F.N3; -Du
# lueurFPl; lueur; NOM; allo; ; allos; allo-s; NOM, CF=N3,  Genre=F, Nombre=Pl; lueur.F.N3-Pl; 3; lueur; .F.N3; -Pl
# INDMSg; IND; DET; un; ; uno; un-o; DET, Genre=M, Nombre=Sg; IND-M; 2; IND; -M
# INDMDu; IND; DET; un; ; unol; un-o-l; DET, Genre=M, Nombre=Du; IND-M-Du; 3; IND; -M; -Du
# INDMPl; IND; DET; un; ; unos; un-o-s; DET, Genre=M, Nombre=Pl; IND-M-Pl; 3; IND; -M; -Pl
# INDFSg; IND; DET; un; ; una; un-a; DET, Genre=F, Nombre=Sg; IND-F; 2; IND; -F
# INDFDu; IND; DET; un; ; unal; un-a-l; DET, Genre=F, Nombre=Du; IND-F-Du; 3; IND; -F; -Du
# INDFPl; IND; DET; un; ; unas; un-a-s; DET, Genre=F, Nombre=Pl; IND-F-Pl; 3; IND; -F; -Pl
# DEFMSg; DEF; DET; l; ; lo; l-o; DET, Genre=M, Nombre=Sg; DEF-M; 2; DEF; -M
# DEFMDu; DEF; DET; l; ; lol; l-o-l; DET, Genre=M, Nombre=Du; DEF-M-Du; 3; DEF; -M; -Du
# DEFMPl; DEF; DET; l; ; los; l-o-s; DET, Genre=M, Nombre=Pl; DEF-M-Pl; 3; DEF; -M; -Pl
# DEFFSg; DEF; DET; l; ; la; l-a; DET, Genre=F, Nombre=Sg; DEF-F; 2; DEF; -F
# DEFFDu; DEF; DET; l; ; lal; l-a-l; DET, Genre=F, Nombre=Du; DEF-F-Du; 3; DEF; -F; -Du
# DEFFPl; DEF; DET; l; ; las; l-a-s; DET, Genre=F, Nombre=Pl; DEF-F-Pl; 3; DEF; -F; -Pl
# DEMMSg; DEM; DET; st; ; sto; st-o; DET, Genre=M, Nombre=Sg; DEM-M; 2; DEM; -M
# DEMMDu; DEM; DET; st; ; stol; st-o-l; DET, Genre=M, Nombre=Du; DEM-M-Du; 3; DEM; -M; -Du
# DEMMPl; DEM; DET; st; ; stos; st-o-s; DET, Genre=M, Nombre=Pl; DEM-M-Pl; 3; DEM; -M; -Pl
# DEMFSg; DEM; DET; st; ; sta; st-a; DET, Genre=F, Nombre=Sg; DEM-F; 2; DEM; -F
# DEMFDu; DEM; DET; st; ; stal; st-a-l; DET, Genre=F, Nombre=Du; DEM-F-Du; 3; DEM; -F; -Du
# DEMFPl; DEM; DET; st; ; stas; st-a-s; DET, Genre=F, Nombre=Pl; DEM-F-Pl; 3; DEM; -F; -Pl
# profondMSg; profond; ADJ; krevas; ; krevaso; krevas-o; ADJ, Genre=M, Nombre=Sg; profond-M; 2; profond; -M
# profondMDu; profond; ADJ; krevas; ; krevasol; krevas-o-l; ADJ, Genre=M, Nombre=Du; profond-M-Du; 3; profond; -M; -Du
# profondMPl; profond; ADJ; krevas; ; krevasos; krevas-o-s; ADJ, Genre=M, Nombre=Pl; profond-M-Pl; 3; profond; -M; -Pl
# profondFSg; profond; ADJ; krevas; ; krevasa; krevas-a; ADJ, Genre=F, Nombre=Sg; profond-F; 2; profond; -F
# profondFDu; profond; ADJ; krevas; ; krevasal; krevas-a-l; ADJ, Genre=F, Nombre=Du; profond-F-Du; 3; profond; -F; -Du
# profondFPl; profond; ADJ; krevas; ; krevasas; krevas-a-s; ADJ, Genre=F, Nombre=Pl; profond-F-Pl; 3; profond; -F; -Pl
# rougeMSg; rouge; ADJ; pastek; ; pasteko; pastek-o; ADJ, Genre=M, Nombre=Sg; rouge-M; 2; rouge; -M
# rougeMDu; rouge; ADJ; pastek; ; pastekol; pastek-o-l; ADJ, Genre=M, Nombre=Du; rouge-M-Du; 3; rouge; -M; -Du
# rougeMPl; rouge; ADJ; pastek; ; pastekos; pastek-o-s; ADJ, Genre=M, Nombre=Pl; rouge-M-Pl; 3; rouge; -M; -Pl
# rougeFSg; rouge; ADJ; pastek; ; pasteka; pastek-a; ADJ, Genre=F, Nombre=Sg; rouge-F; 2; rouge; -F
# rougeFDu; rouge; ADJ; pastek; ; pastekal; pastek-a-l; ADJ, Genre=F, Nombre=Du; rouge-F-Du; 3; rouge; -F; -Du
# rougeFPl; rouge; ADJ; pastek; ; pastekas; pastek-a-s; ADJ, Genre=F, Nombre=Pl; rouge-F-Pl; 3; rouge; -F; -Pl
# effrayeMSg; effrayé; ADJ; turmant; ; turmanto; turmant-o; ADJ, Genre=M, Nombre=Sg; effrayé-M; 2; effrayé; -M
# effrayeMDu; effrayé; ADJ; turmant; ; turmantol; turmant-o-l; ADJ, Genre=M, Nombre=Du; effrayé-M-Du; 3; effrayé; -M; -Du
# effrayeMPl; effrayé; ADJ; turmant; ; turmantos; turmant-o-s; ADJ, Genre=M, Nombre=Pl; effrayé-M-Pl; 3; effrayé; -M; -Pl
# effrayeFSg; effrayé; ADJ; turmant; ; turmanta; turmant-a; ADJ, Genre=F, Nombre=Sg; effrayé-F; 2; effrayé; -F
# effrayeFDu; effrayé; ADJ; turmant; ; turmantal; turmant-a-l; ADJ, Genre=F, Nombre=Du; effrayé-F-Du; 3; effrayé; -F; -Du
# effrayeFPl; effrayé; ADJ; turmant; ; turmantas; turmant-a-s; ADJ, Genre=F, Nombre=Pl; effrayé-F-Pl; 3; effrayé; -F; -Pl
# terribleMSg; terrible; ADJ; atros; ; atroso; atros-o; ADJ, Genre=M, Nombre=Sg; terrible-M; 2; terrible; -M
# terribleMDu; terrible; ADJ; atros; ; atrosol; atros-o-l; ADJ, Genre=M, Nombre=Du; terrible-M-Du; 3; terrible; -M; -Du
# terribleMPl; terrible; ADJ; atros; ; atrosos; atros-o-s; ADJ, Genre=M, Nombre=Pl; terrible-M-Pl; 3; terrible; -M; -Pl
# terribleFSg; terrible; ADJ; atros; ; atrosa; atros-a; ADJ, Genre=F, Nombre=Sg; terrible-F; 2; terrible; -F
# terribleFDu; terrible; ADJ; atros; ; atrosal; atros-a-l; ADJ, Genre=F, Nombre=Du; terrible-F-Du; 3; terrible; -F; -Du
# terribleFPl; terrible; ADJ; atros; ; atrosas; atros-a-s; ADJ, Genre=F, Nombre=Pl; terrible-F-Pl; 3; terrible; -F; -Pl
# furieuxMSg; furieux; ADJ; raʒ; ; raʒo; raʒ-o; ADJ, Genre=M, Nombre=Sg; furieux-M; 2; furieux; -M
# furieuxMDu; furieux; ADJ; raʒ; ; raʒol; raʒ-o-l; ADJ, Genre=M, Nombre=Du; furieux-M-Du; 3; furieux; -M; -Du
# furieuxMPl; furieux; ADJ; raʒ; ; raʒos; raʒ-o-s; ADJ, Genre=M, Nombre=Pl; furieux-M-Pl; 3; furieux; -M; -Pl
# furieuxFSg; furieux; ADJ; raʒ; ; raʒa; raʒ-a; ADJ, Genre=F, Nombre=Sg; furieux-F; 2; furieux; -F
# furieuxFDu; furieux; ADJ; raʒ; ; raʒal; raʒ-a-l; ADJ, Genre=F, Nombre=Du; furieux-F-Du; 3; furieux; -F; -Du
# furieuxFPl; furieux; ADJ; raʒ; ; raʒas; raʒ-a-s; ADJ, Genre=F, Nombre=Pl; furieux-F-Pl; 3; furieux; -F; -Pl
# blancMSg; blanc; ADJ; neʒ; ; neʒo; neʒ-o; ADJ, Genre=M, Nombre=Sg; blanc-M; 2; blanc; -M
# blancMDu; blanc; ADJ; neʒ; ; neʒol; neʒ-o-l; ADJ, Genre=M, Nombre=Du; blanc-M-Du; 3; blanc; -M; -Du
# blancMPl; blanc; ADJ; neʒ; ; neʒos; neʒ-o-s; ADJ, Genre=M, Nombre=Pl; blanc-M-Pl; 3; blanc; -M; -Pl
# blancFSg; blanc; ADJ; neʒ; ; neʒa; neʒ-a; ADJ, Genre=F, Nombre=Sg; blanc-F; 2; blanc; -F
# blancFDu; blanc; ADJ; neʒ; ; neʒal; neʒ-a-l; ADJ, Genre=F, Nombre=Du; blanc-F-Du; 3; blanc; -F; -Du
# blancFPl; blanc; ADJ; neʒ; ; neʒas; neʒ-a-s; ADJ, Genre=F, Nombre=Pl; blanc-F-Pl; 3; blanc; -F; -Pl
# grandMSg; grand; ADJ; makros; ; makroso; makros-o; ADJ, Genre=M, Nombre=Sg; grand-M; 2; grand; -M
# grandMDu; grand; ADJ; makros; ; makrosol; makros-o-l; ADJ, Genre=M, Nombre=Du; grand-M-Du; 3; grand; -M; -Du
# grandMPl; grand; ADJ; makros; ; makrosos; makros-o-s; ADJ, Genre=M, Nombre=Pl; grand-M-Pl; 3; grand; -M; -Pl
# grandFSg; grand; ADJ; makros; ; makrosa; makros-a; ADJ, Genre=F, Nombre=Sg; grand-F; 2; grand; -F
# grandFDu; grand; ADJ; makros; ; makrosal; makros-a-l; ADJ, Genre=F, Nombre=Du; grand-F-Du; 3; grand; -F; -Du
# grandFPl; grand; ADJ; makros; ; makrosas; makros-a-s; ADJ, Genre=F, Nombre=Pl; grand-F-Pl; 3; grand; -F; -Pl
# differentMSg; différent; ADJ; otr; ; otro; otr-o; ADJ, Genre=M, Nombre=Sg; différent-M; 2; différent; -M
# differentMDu; différent; ADJ; otr; ; otrol; otr-o-l; ADJ, Genre=M, Nombre=Du; différent-M-Du; 3; différent; -M; -Du
# differentMPl; différent; ADJ; otr; ; otros; otr-o-s; ADJ, Genre=M, Nombre=Pl; différent-M-Pl; 3; différent; -M; -Pl
# differentFSg; différent; ADJ; otr; ; otra; otr-a; ADJ, Genre=F, Nombre=Sg; différent-F; 2; différent; -F
# differentFDu; différent; ADJ; otr; ; otral; otr-a-l; ADJ, Genre=F, Nombre=Du; différent-F-Du; 3; différent; -F; -Du
# differentFPl; différent; ADJ; otr; ; otras; otr-a-s; ADJ, Genre=F, Nombre=Pl; différent-F-Pl; 3; différent; -F; -Pl
# suivantMSg; suivant; ADJ; proʃen; ; proʃeno; proʃen-o; ADJ, Genre=M, Nombre=Sg; suivant-M; 2; suivant; -M
# suivantMDu; suivant; ADJ; proʃen; ; proʃenol; proʃen-o-l; ADJ, Genre=M, Nombre=Du; suivant-M-Du; 3; suivant; -M; -Du
# suivantMPl; suivant; ADJ; proʃen; ; proʃenos; proʃen-o-s; ADJ, Genre=M, Nombre=Pl; suivant-M-Pl; 3; suivant; -M; -Pl
# suivantFSg; suivant; ADJ; proʃen; ; proʃena; proʃen-a; ADJ, Genre=F, Nombre=Sg; suivant-F; 2; suivant; -F
# suivantFDu; suivant; ADJ; proʃen; ; proʃenal; proʃen-a-l; ADJ, Genre=F, Nombre=Du; suivant-F-Du; 3; suivant; -F; -Du
# suivantFPl; suivant; ADJ; proʃen; ; proʃenas; proʃen-a-s; ADJ, Genre=F, Nombre=Pl; suivant-F-Pl; 3; suivant; -F; -Pl
# petitMSg; petit; ADJ; mikron; ; mikrono; mikron-o; ADJ, Genre=M, Nombre=Sg; petit-M; 2; petit; -M
# petitMDu; petit; ADJ; mikron; ; mikronol; mikron-o-l; ADJ, Genre=M, Nombre=Du; petit-M-Du; 3; petit; -M; -Du
# petitMPl; petit; ADJ; mikron; ; mikronos; mikron-o-s; ADJ, Genre=M, Nombre=Pl; petit-M-Pl; 3; petit; -M; -Pl
# petitFSg; petit; ADJ; mikron; ; mikrona; mikron-a; ADJ, Genre=F, Nombre=Sg; petit-F; 2; petit; -F
# petitFDu; petit; ADJ; mikron; ; mikronal; mikron-a-l; ADJ, Genre=F, Nombre=Du; petit-F-Du; 3; petit; -F; -Du
# petitFPl; petit; ADJ; mikron; ; mikronas; mikron-a-s; ADJ, Genre=F, Nombre=Pl; petit-F-Pl; 3; petit; -F; -Pl
# blesseMSg; blessé; ADJ; estrop; ; estropo; estrop-o; ADJ, Genre=M, Nombre=Sg; blessé-M; 2; blessé; -M
# blesseMDu; blessé; ADJ; estrop; ; estropol; estrop-o-l; ADJ, Genre=M, Nombre=Du; blessé-M-Du; 3; blessé; -M; -Du
# blesseMPl; blessé; ADJ; estrop; ; estropos; estrop-o-s; ADJ, Genre=M, Nombre=Pl; blessé-M-Pl; 3; blessé; -M; -Pl
# blesseFSg; blessé; ADJ; estrop; ; estropa; estrop-a; ADJ, Genre=F, Nombre=Sg; blessé-F; 2; blessé; -F
# blesseFDu; blessé; ADJ; estrop; ; estropal; estrop-a-l; ADJ, Genre=F, Nombre=Du; blessé-F-Du; 3; blessé; -F; -Du
# blesseFPl; blessé; ADJ; estrop; ; estropas; estrop-a-s; ADJ, Genre=F, Nombre=Pl; blessé-F-Pl; 3; blessé; -F; -Pl
# noirMSg; noir; ADJ; lamer; ; lamero; lamer-o; ADJ, Genre=M, Nombre=Sg; noir-M; 2; noir; -M
# noirMDu; noir; ADJ; lamer; ; lamerol; lamer-o-l; ADJ, Genre=M, Nombre=Du; noir-M-Du; 3; noir; -M; -Du
# noirMPl; noir; ADJ; lamer; ; lameros; lamer-o-s; ADJ, Genre=M, Nombre=Pl; noir-M-Pl; 3; noir; -M; -Pl
# noirFSg; noir; ADJ; lamer; ; lamera; lamer-a; ADJ, Genre=F, Nombre=Sg; noir-F; 2; noir; -F
# noirFDu; noir; ADJ; lamer; ; lameral; lamer-a-l; ADJ, Genre=F, Nombre=Du; noir-F-Du; 3; noir; -F; -Du
# noirFPl; noir; ADJ; lamer; ; lameras; lamer-a-s; ADJ, Genre=F, Nombre=Pl; noir-F-Pl; 3; noir; -F; -Pl
# courageuxMSg; courageux; ADJ; brav; ; bravo; brav-o; ADJ, Genre=M, Nombre=Sg; courageux-M; 2; courageux; -M
# courageuxMDu; courageux; ADJ; brav; ; bravol; brav-o-l; ADJ, Genre=M, Nombre=Du; courageux-M-Du; 3; courageux; -M; -Du
# courageuxMPl; courageux; ADJ; brav; ; bravos; brav-o-s; ADJ, Genre=M, Nombre=Pl; courageux-M-Pl; 3; courageux; -M; -Pl
# courageuxFSg; courageux; ADJ; brav; ; brava; brav-a; ADJ, Genre=F, Nombre=Sg; courageux-F; 2; courageux; -F
# courageuxFDu; courageux; ADJ; brav; ; braval; brav-a-l; ADJ, Genre=F, Nombre=Du; courageux-F-Du; 3; courageux; -F; -Du
# courageuxFPl; courageux; ADJ; brav; ; bravas; brav-a-s; ADJ, Genre=F, Nombre=Pl; courageux-F-Pl; 3; courageux; -F; -Pl
# DEVANT; DEVANT; PREP; nen; ; nen; nen; PREP; devant; 1; devant
# DE; DE; PREP; ad; ; ad; ad; PREP; de; 1; de
# ENTRE; ENTRE; PREP; ron; ; ron; ron; PREP; ENTRE; 1; ENTRE
# DERRIERE; DERRIÈRE; PREP; wen; ; wen; wen; PREP; derrière; 1; derrière
# APRES; APRÈS; PREP; gur; ; gur; gur; PREP; après; 1; après
# A; À; PREP; ar; ; ar; ar; PREP; à; 1; à
# DANS; DANS; PREP; sor; ; sor; sor; PREP; dans; 1; dans
# SUR; SUR; PREP; puw; ; puw; puw; PREP; sur; 1; sur
# VERS; VERS; PREP; uka; ; uka; uka; PREP; vers; 1; vers
# AVEC; AVEC; PREP; kej; ; kej; kej; PREP; avec; 1; avec
