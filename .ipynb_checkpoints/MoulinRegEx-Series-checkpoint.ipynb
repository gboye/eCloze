# %%
#import re
import sys, codecs, optparse, glob, os
import string, yaml, warnings
import random as rd
from ToolsMoodleXML2 import *

# %%
nKalaba="K2"
annee="17"
limiteDonnees=1500
freeSpace=False
dossier="/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/Kalaba-Project/%s-%s"%(annee,nKalaba)
enonces=["Forme-Traduction","Proprietes-Forme"]
theme="%s-%s-A1"%(annee,nKalaba)
#enonces=["Theme","Version"]
#theme="Traductions"
#enonces=["Theme"]
#enonces=["Ordre"]
#theme="Syntagmes"

# %%
from os.path import expanduser
home = expanduser("~")
repertoire=home+dossier
base=repertoire+"/"

# %%
def chaine2utf8(chaine):
    if type(chaine)==str:
        result=unicode(chaine.decode('utf8'))
    elif type(chaine)==unicode:
        result=chaine
    return result

# %%
def substituerChamps(chaine, substituts):
    result=chaine
    for substitut in substituts:
        result=result.replace(substitut,substituts[substitut])
    return result

# %%
def preparationDonnees():
    for ligne in donneesLignes:
        if not (ligne.strip().strip(";")=="" or ligne.startswith("#")):
            temp=ligne.strip().split(";")
            result={"boucle":[temp],"conclusion":[]}
            titre=makeChamps(configuration[u"Titre"],temp).encode('utf8')
            donnees.append({titre:result})
    return

# %%
def numerotationDonnees(donnees):
    result={}
    for nDonnee, donnee in enumerate(donnees):
        result[u"#%d#"%(nDonnee+1)]=chaine2utf8(donnee)
    return result

# %%
def preparationConsigne(consigne,clozes,substituts):
    result=[]
    reponse=[]
    txtClozes=[c for c in clozes if clozes[c]=="TXT"]
    for element in consigne:
        chaine=chaine2utf8(element)
        if chaine in clozes:
            champ=substituerChamps(chaine,substituts)
            if clozes[chaine]=="TXT":
                result.append(champ)
            else:
                reponse.append(champ)
        else:
            result.append(chaine)
    return (result,reponse)

# %%
for enonce in enonces:
    yamlFichier=base+theme+"-"+enonce+".yaml"
    csvFichier=base+theme+".txt"
    boolEX=False
            
    with open(yamlFichier, 'r') as stream:
        configuration=yaml.load(stream)

    with open(csvFichier, 'r') as file:
        donneesLignes=file.readlines()
    
    if len(donneesLignes)>limiteDonnees:
        donneesLignes=rd.sample(donneesLignes,limiteDonnees)

    donnees=[]

    preparationDonnees()

        
    categorie=configuration[u"Catégorie"]+"/RX"
    consigne=[configuration[u"Boucle"][u"début"]]+configuration[u"Boucle"][u"contenu"]
    boucleCLOZE=configuration[u"Boucle"][u"Cloze"]
    globalWrap=[configuration[u"Décor"][u"fond"]+configuration[u"Décor"][u"entete"]+configuration[u"Global"][u"début"],configuration[u"Global"]["fin"]]
    questions=XMLSeries(categorie)
    clozes=numerotationDonnees(boucleCLOZE)
    for exercices in donnees:
        for exercice in exercices:
            titre=chaine2utf8(exercice)
            substituts=numerotationDonnees(exercices[exercice]['boucle'][0])
            regexConsigne,regexReponse= preparationConsigne(consigne,clozes,substituts)
            regexConsigne=regexConsigne
            if freeSpace:
                freeSpaceReponses=[]
                for reponse in regexReponse:
                    freeSpaceReponses.append(re.sub(r"\s+",r"\s+",reponse))
                regexReponse.extend(freeSpaceReponses)
            questions.addExercice(RegExExercice(titre,[globalWrap[0]]+regexConsigne,regexReponse,usehint="2"))

    xmlOutput=MoodleXML()
    xmlOutput.addQuiz(questions.getSeries())

    xmlFichier=yamlFichier.split(".")[0]+"-RX.xml"

    with codecs.open(xmlFichier, 'w',encoding="utf8") as output:
        output.write(xmlOutput.getXML())
# Out:
# QUESTION
# Donnez le sens général de la forme: godufom
# Réponse :
# REPONSE
# effrayé
# QUESTION
# Donnez le sens général de la forme: godufel
# Réponse :
# REPONSE
# effrayé
# QUESTION
# Donnez le sens général de la forme: godufir
# Réponse :
# REPONSE
# effrayé
# QUESTION
# Donnez le sens général de la forme: godufij
# Réponse :
# REPONSE
# effrayé
# QUESTION
# Donnez le sens général de la forme: godufija
# Réponse :
# REPONSE
# effrayé
# QUESTION
# Donnez le sens général de la forme: godufiju
# Réponse :
# REPONSE
# effrayé
# QUESTION
# Donnez le sens général de la forme: godufoz
# Réponse :
# REPONSE
# effrayé
# QUESTION
# Donnez le sens général de la forme: godufozi
# Réponse :
# REPONSE
# effrayé
# QUESTION
# Donnez le sens général de la forme: godufozo
# Réponse :
# REPONSE
# effrayé
# QUESTION
# Donnez le sens général de la forme: pupufom
# Réponse :
# REPONSE
# suivant
# QUESTION
# Donnez le sens général de la forme: pupufel
# Réponse :
# REPONSE
# suivant
# QUESTION
# Donnez le sens général de la forme: pupufir
# Réponse :
# REPONSE
# suivant
# QUESTION
# Donnez le sens général de la forme: pupufij
# Réponse :
# REPONSE
# suivant
# QUESTION
# Donnez le sens général de la forme: pupufija
# Réponse :
# REPONSE
# suivant
# QUESTION
# Donnez le sens général de la forme: pupufiju
# Réponse :
# REPONSE
# suivant
# QUESTION
# Donnez le sens général de la forme: pupufoz
# Réponse :
# REPONSE
# suivant
# QUESTION
# Donnez le sens général de la forme: pupufozi
# Réponse :
# REPONSE
# suivant
# QUESTION
# Donnez le sens général de la forme: pupufozo
# Réponse :
# REPONSE
# suivant
# QUESTION
# Donnez le sens général de la forme: fuʒopaom
# Réponse :
# REPONSE
# courageux
# QUESTION
# Donnez le sens général de la forme: fuʒopael
# Réponse :
# REPONSE
# courageux
# QUESTION
# Donnez le sens général de la forme: fuʒopair
# Réponse :
# REPONSE
# courageux
# QUESTION
# Donnez le sens général de la forme: fuʒopaij
# Réponse :
# REPONSE
# courageux
# QUESTION
# Donnez le sens général de la forme: fuʒopaija
# Réponse :
# REPONSE
# courageux
# QUESTION
# Donnez le sens général de la forme: fuʒopaiju
# Réponse :
# REPONSE
# courageux
# QUESTION
# Donnez le sens général de la forme: fuʒopaoz
# Réponse :
# REPONSE
# courageux
# QUESTION
# Donnez le sens général de la forme: fuʒopaozi
# Réponse :
# REPONSE
# courageux
# QUESTION
# Donnez le sens général de la forme: fuʒopaozo
# Réponse :
# REPONSE
# courageux
# QUESTION
# Donnez le sens général de la forme: juzoθom
# Réponse :
# REPONSE
# grand
# QUESTION
# Donnez le sens général de la forme: juzoθel
# Réponse :
# REPONSE
# grand
# QUESTION
# Donnez le sens général de la forme: juzoθir
# Réponse :
# REPONSE
# grand
# QUESTION
# Donnez le sens général de la forme: juzoθij
# Réponse :
# REPONSE
# grand
# QUESTION
# Donnez le sens général de la forme: juzoθija
# Réponse :
# REPONSE
# grand
# QUESTION
# Donnez le sens général de la forme: juzoθiju
# Réponse :
# REPONSE
# grand
# QUESTION
# Donnez le sens général de la forme: juzoθoz
# Réponse :
# REPONSE
# grand
# QUESTION
# Donnez le sens général de la forme: juzoθozi
# Réponse :
# REPONSE
# grand
# QUESTION
# Donnez le sens général de la forme: juzoθozo
# Réponse :
# REPONSE
# grand
# QUESTION
# Donnez le sens général de la forme: zoʒogoom
# Réponse :
# REPONSE
# noir
# QUESTION
# Donnez le sens général de la forme: zoʒogoel
# Réponse :
# REPONSE
# noir
# QUESTION
# Donnez le sens général de la forme: zoʒogoir
# Réponse :
# REPONSE
# noir
# QUESTION
# Donnez le sens général de la forme: zoʒogoij
# Réponse :
# REPONSE
# noir
# QUESTION
# Donnez le sens général de la forme: zoʒogoija
# Réponse :
# REPONSE
# noir
# QUESTION
# Donnez le sens général de la forme: zoʒogoiju
# Réponse :
# REPONSE
# noir
# QUESTION
# Donnez le sens général de la forme: zoʒogooz
# Réponse :
# REPONSE
# noir
# QUESTION
# Donnez le sens général de la forme: zoʒogoozi
# Réponse :
# REPONSE
# noir
# QUESTION
# Donnez le sens général de la forme: zoʒogoozo
# Réponse :
# REPONSE
# noir
# QUESTION
# Donnez le sens général de la forme: notuziom
# Réponse :
# REPONSE
# rouge
# QUESTION
# Donnez le sens général de la forme: notuziel
# Réponse :
# REPONSE
# rouge
# QUESTION
# Donnez le sens général de la forme: notuziir
# Réponse :
# REPONSE
# rouge
# QUESTION
# Donnez le sens général de la forme: notuziij
# Réponse :
# REPONSE
# rouge
# QUESTION
# Donnez le sens général de la forme: notuziija
# Réponse :
# REPONSE
# rouge
# QUESTION
# Donnez le sens général de la forme: notuziiju
# Réponse :
# REPONSE
# rouge
# QUESTION
# Donnez le sens général de la forme: notuzioz
# Réponse :
# REPONSE
# rouge
# QUESTION
# Donnez le sens général de la forme: notuziozi
# Réponse :
# REPONSE
# rouge
# QUESTION
# Donnez le sens général de la forme: notuziozo
# Réponse :
# REPONSE
# rouge
# QUESTION
# Donnez le sens général de la forme: motukom
# Réponse :
# REPONSE
# blanc
# QUESTION
# Donnez le sens général de la forme: motukel
# Réponse :
# REPONSE
# blanc
# QUESTION
# Donnez le sens général de la forme: motukir
# Réponse :
# REPONSE
# blanc
# QUESTION
# Donnez le sens général de la forme: motukij
# Réponse :
# REPONSE
# blanc
# QUESTION
# Donnez le sens général de la forme: motukija
# Réponse :
# REPONSE
# blanc
# QUESTION
# Donnez le sens général de la forme: motukiju
# Réponse :
# REPONSE
# blanc
# QUESTION
# Donnez le sens général de la forme: motukoz
# Réponse :
# REPONSE
# blanc
# QUESTION
# Donnez le sens général de la forme: motukozi
# Réponse :
# REPONSE
# blanc
# QUESTION
# Donnez le sens général de la forme: motukozo
# Réponse :
# REPONSE
# blanc
# QUESTION
# Donnez le sens général de la forme: lovosom
# Réponse :
# REPONSE
# terrible
# QUESTION
# Donnez le sens général de la forme: lovosel
# Réponse :
# REPONSE
# terrible
# QUESTION
# Donnez le sens général de la forme: lovosir
# Réponse :
# REPONSE
# terrible
# QUESTION
# Donnez le sens général de la forme: lovosij
# Réponse :
# REPONSE
# terrible
# QUESTION
# Donnez le sens général de la forme: lovosija
# Réponse :
# REPONSE
# terrible
# QUESTION
# Donnez le sens général de la forme: lovosiju
# Réponse :
# REPONSE
# terrible
# QUESTION
# Donnez le sens général de la forme: lovosoz
# Réponse :
# REPONSE
# terrible
# QUESTION
# Donnez le sens général de la forme: lovosozi
# Réponse :
# REPONSE
# terrible
# QUESTION
# Donnez le sens général de la forme: lovosozo
# Réponse :
# REPONSE
# terrible
# QUESTION
# Donnez le sens général de la forme: voŋudom
# Réponse :
# REPONSE
# blessé
# QUESTION
# Donnez le sens général de la forme: voŋudel
# Réponse :
# REPONSE
# blessé
# QUESTION
# Donnez le sens général de la forme: voŋudir
# Réponse :
# REPONSE
# blessé
# QUESTION
# Donnez le sens général de la forme: voŋudij
# Réponse :
# REPONSE
# blessé
# QUESTION
# Donnez le sens général de la forme: voŋudija
# Réponse :
# REPONSE
# blessé
# QUESTION
# Donnez le sens général de la forme: voŋudiju
# Réponse :
# REPONSE
# blessé
# QUESTION
# Donnez le sens général de la forme: voŋudoz
# Réponse :
# REPONSE
# blessé
# QUESTION
# Donnez le sens général de la forme: voŋudozi
# Réponse :
# REPONSE
# blessé
# QUESTION
# Donnez le sens général de la forme: voŋudozo
# Réponse :
# REPONSE
# blessé
# QUESTION
# Donnez le sens général de la forme: zeʃugom
# Réponse :
# REPONSE
# profond
# QUESTION
# Donnez le sens général de la forme: zeʃugel
# Réponse :
# REPONSE
# profond
# QUESTION
# Donnez le sens général de la forme: zeʃugir
# Réponse :
# REPONSE
# profond
# QUESTION
# Donnez le sens général de la forme: zeʃugij
# Réponse :
# REPONSE
# profond
# QUESTION
# Donnez le sens général de la forme: zeʃugija
# Réponse :
# REPONSE
# profond
# QUESTION
# Donnez le sens général de la forme: zeʃugiju
# Réponse :
# REPONSE
# profond
# QUESTION
# Donnez le sens général de la forme: zeʃugoz
# Réponse :
# REPONSE
# profond
# QUESTION
# Donnez le sens général de la forme: zeʃugozi
# Réponse :
# REPONSE
# profond
# QUESTION
# Donnez le sens général de la forme: zeʃugozo
# Réponse :
# REPONSE
# profond
# QUESTION
# Donnez le sens général de la forme: foteθom
# Réponse :
# REPONSE
# furieux
# QUESTION
# Donnez le sens général de la forme: foteθel
# Réponse :
# REPONSE
# furieux
# QUESTION
# Donnez le sens général de la forme: foteθir
# Réponse :
# REPONSE
# furieux
# QUESTION
# Donnez le sens général de la forme: foteθij
# Réponse :
# REPONSE
# furieux
# QUESTION
# Donnez le sens général de la forme: foteθija
# Réponse :
# REPONSE
# furieux
# QUESTION
# Donnez le sens général de la forme: foteθiju
# Réponse :
# REPONSE
# furieux
# QUESTION
# Donnez le sens général de la forme: foteθoz
# Réponse :
# REPONSE
# furieux
# QUESTION
# Donnez le sens général de la forme: foteθozi
# Réponse :
# REPONSE
# furieux
# QUESTION
# Donnez le sens général de la forme: foteθozo
# Réponse :
# REPONSE
# furieux
# QUESTION
# Donnez le sens général de la forme: nufoduom
# Réponse :
# REPONSE
# petit
# QUESTION
# Donnez le sens général de la forme: nufoduel
# Réponse :
# REPONSE
# petit
# QUESTION
# Donnez le sens général de la forme: nufoduir
# Réponse :
# REPONSE
# petit
# QUESTION
# Donnez le sens général de la forme: nufoduij
# Réponse :
# REPONSE
# petit
# QUESTION
# Donnez le sens général de la forme: nufoduija
# Réponse :
# REPONSE
# petit
# QUESTION
# Donnez le sens général de la forme: nufoduiju
# Réponse :
# REPONSE
# petit
# QUESTION
# Donnez le sens général de la forme: nufoduoz
# Réponse :
# REPONSE
# petit
# QUESTION
# Donnez le sens général de la forme: nufoduozi
# Réponse :
# REPONSE
# petit
# QUESTION
# Donnez le sens général de la forme: nufoduozo
# Réponse :
# REPONSE
# petit
# QUESTION
# Donnez le sens général de la forme: ðudobuom
# Réponse :
# REPONSE
# différent
# QUESTION
# Donnez le sens général de la forme: ðudobuel
# Réponse :
# REPONSE
# différent
# QUESTION
# Donnez le sens général de la forme: ðudobuir
# Réponse :
# REPONSE
# différent
# QUESTION
# Donnez le sens général de la forme: ðudobuij
# Réponse :
# REPONSE
# différent
# QUESTION
# Donnez le sens général de la forme: ðudobuija
# Réponse :
# REPONSE
# différent
# QUESTION
# Donnez le sens général de la forme: ðudobuiju
# Réponse :
# REPONSE
# différent
# QUESTION
# Donnez le sens général de la forme: ðudobuoz
# Réponse :
# REPONSE
# différent
# QUESTION
# Donnez le sens général de la forme: ðudobuozi
# Réponse :
# REPONSE
# différent
# QUESTION
# Donnez le sens général de la forme: ðudobuozo
# Réponse :
# REPONSE
# différent
# QUESTION
# Donnez le sens général de la forme: lanus
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lakas
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lados
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: labis
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lanur
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lakar
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lador
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: labir
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lanuv
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lakav
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: ladov
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: labiv
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lunus
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lukas
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: ludos
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lubis
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lunur
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lukar
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: ludor
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lubir
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lunuv
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lukav
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: ludov
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lubiv
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lonus
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lokas
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lodos
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lobis
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lonur
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lokar
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lodor
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lobir
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lonuv
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lokav
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lodov
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: lobiv
# Réponse :
# REPONSE
# IND
# QUESTION
# Donnez le sens général de la forme: ganus
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gakas
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gados
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gabis
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: ganur
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gakar
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gador
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gabir
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: ganuv
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gakav
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gadov
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gabiv
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gunus
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gukas
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gudos
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gubis
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gunur
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gukar
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gudor
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gubir
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gunuv
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gukav
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gudov
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gubiv
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gonus
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gokas
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: godos
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gobis
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gonur
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gokar
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: godor
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gobir
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gonuv
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gokav
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: godov
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: gobiv
# Réponse :
# REPONSE
# DEF
# QUESTION
# Donnez le sens général de la forme: dave
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: tave
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: nave
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: rave
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: davr
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: tavr
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: navr
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: ravr
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: davv
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: tavv
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: navv
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: ravv
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: duve
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: tuve
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: nuve
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: ruve
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: duvr
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: tuvr
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: nuvr
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: ruvr
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: duvv
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: tuvv
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: nuvv
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: ruvv
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: deve
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: teve
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: neve
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: reve
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: devr
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: tevr
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: nevr
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: revr
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: devv
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: tevv
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: nevv
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: revv
# Réponse :
# REPONSE
# DEM
# QUESTION
# Donnez le sens général de la forme: ʃubiroiz
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroak
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroum
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroizin
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroakin
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroumin
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroizoŋ
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroakoŋ
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroumoŋ
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroizebo
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroakebo
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroumebo
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroizebu
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroakebu
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroumebu
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroizebe
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroakebe
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: ʃubiroumebe
# Réponse :
# REPONSE
# prendre
# QUESTION
# Donnez le sens général de la forme: nupotiz
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotak
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotum
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotizin
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotakin
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotumin
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotizoŋ
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotakoŋ
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotumoŋ
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotizebo
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotakebo
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotumebo
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotizebu
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotakebu
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotumebu
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotizebe
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotakebe
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: nupotumebe
# Réponse :
# REPONSE
# courir
# QUESTION
# Donnez le sens général de la forme: koðoruiz
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruak
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruum
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruizin
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruakin
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruumin
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruizoŋ
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruakoŋ
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruumoŋ
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruizebo
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruakebo
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruumebo
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruizebu
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruakebu
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruumebu
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruizebe
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruakebe
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: koðoruumebe
# Réponse :
# REPONSE
# jeter
# QUESTION
# Donnez le sens général de la forme: tuðobiz
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobak
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobum
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobizin
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobakin
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobumin
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobizoŋ
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobakoŋ
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobumoŋ
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobizebo
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobakebo
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobumebo
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobizebu
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobakebu
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobumebu
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobizebe
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobakebe
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: tuðobumebe
# Réponse :
# REPONSE
# transpercer
# QUESTION
# Donnez le sens général de la forme: ʒopuluiz
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluak
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluum
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluizin
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluakin
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluumin
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluizoŋ
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluakoŋ
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluumoŋ
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluizebo
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluakebo
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluumebo
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluizebu
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluakebu
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluumebu
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluizebe
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluakebe
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: ʒopuluumebe
# Réponse :
# REPONSE
# envahir
# QUESTION
# Donnez le sens général de la forme: toðuniz
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunak
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunum
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunizin
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunakin
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunumin
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunizoŋ
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunakoŋ
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunumoŋ
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunizebo
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunakebo
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunumebo
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunizebu
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunakebu
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunumebu
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunizebe
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunakebe
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: toðunumebe
# Réponse :
# REPONSE
# planter
# QUESTION
# Donnez le sens général de la forme: kujoʃiz
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃak
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃum
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃizin
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃakin
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃumin
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃizoŋ
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃakoŋ
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃumoŋ
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃizebo
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃakebo
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃumebo
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃizebu
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃakebu
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃumebu
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃizebe
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃakebe
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: kujoʃumebe
# Réponse :
# REPONSE
# être
# QUESTION
# Donnez le sens général de la forme: lðuŋufiz
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufak
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufum
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufizin
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufakin
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufumin
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufizoŋ
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufakoŋ
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufumoŋ
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufizebo
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufakebo
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufumebo
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufizebu
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufakebu
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufumebu
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufizebe
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufakebe
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: lðuŋufumebe
# Réponse :
# REPONSE
# disparaître
# QUESTION
# Donnez le sens général de la forme: dotupiz
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupak
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupum
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupizin
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupakin
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupumin
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupizoŋ
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupakoŋ
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupumoŋ
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupizebo
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupakebo
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupumebo
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupizebu
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupakebu
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupumebu
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupizebe
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupakebe
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: dotupumebe
# Réponse :
# REPONSE
# sortir
# QUESTION
# Donnez le sens général de la forme: fagoruiz
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruak
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruum
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruizin
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruakin
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruumin
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruizoŋ
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruakoŋ
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruumoŋ
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruizebo
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruakebo
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruumebo
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruizebu
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruakebu
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruumebu
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruizebe
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruakebe
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: fagoruumebe
# Réponse :
# REPONSE
# transformer
# QUESTION
# Donnez le sens général de la forme: guŋuniz
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunak
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunum
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunizin
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunakin
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunumin
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunizoŋ
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunakoŋ
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunumoŋ
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunizebo
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunakebo
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunumebo
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunizebu
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunakebu
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunumebu
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunizebe
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunakebe
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: guŋunumebe
# Réponse :
# REPONSE
# voir
# QUESTION
# Donnez le sens général de la forme: noðoŋuiz
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuak
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuum
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuizin
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuakin
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuumin
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuizoŋ
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuakoŋ
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuumoŋ
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuizebo
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuakebo
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuumebo
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuizebu
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuakebu
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuumebu
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuizebe
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuakebe
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: noðoŋuumebe
# Réponse :
# REPONSE
# apporter
# QUESTION
# Donnez le sens général de la forme: feθaniz
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanak
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanum
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanizin
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanakin
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanumin
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanizoŋ
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanakoŋ
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanumoŋ
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanizebo
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanakebo
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanumebo
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanizebu
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanakebu
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanumebu
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanizebe
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanakebe
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: feθanumebe
# Réponse :
# REPONSE
# fuir
# QUESTION
# Donnez le sens général de la forme: mulukiz
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukak
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukum
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukizin
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukakin
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukumin
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukizoŋ
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukakoŋ
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukumoŋ
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukizebo
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukakebo
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukumebo
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukizebu
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukakebu
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukumebu
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukizebe
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukakebe
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: mulukumebe
# Réponse :
# REPONSE
# dévorer
# QUESTION
# Donnez le sens général de la forme: logupose
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: logupege
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: logupaŋe
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: loguposam
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: logupegam
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: logupaŋam
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: loguposo
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: logupego
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: logupaŋo
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: loguposar
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: logupegar
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: logupaŋar
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: loguposarun
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: logupegarun
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: logupaŋarun
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: loguposarim
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: logupegarim
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: logupaŋarim
# Réponse :
# REPONSE
# protéger
# QUESTION
# Donnez le sens général de la forme: fuðeduose
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduege
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduaŋe
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduosam
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduegam
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduaŋam
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduoso
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduego
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduaŋo
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduosar
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduegar
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduaŋar
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduosarun
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduegarun
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduaŋarun
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduosarim
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduegarim
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: fuðeduaŋarim
# Réponse :
# REPONSE
# passer
# QUESTION
# Donnez le sens général de la forme: rozosose
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozosege
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozosaŋe
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozososam
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozosegam
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozosaŋam
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozososo
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozosego
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozosaŋo
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozososar
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozosegar
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozosaŋar
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozososarun
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozosegarun
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozosaŋarun
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozososarim
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozosegarim
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: rozosaŋarim
# Réponse :
# REPONSE
# aller
# QUESTION
# Donnez le sens général de la forme: tθuʒofose
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofege
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofaŋe
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofosam
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofegam
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofaŋam
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofoso
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofego
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofaŋo
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofosar
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofegar
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofaŋar
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofosarun
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofegarun
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofaŋarun
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofosarim
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofegarim
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: tθuʒofaŋarim
# Réponse :
# REPONSE
# sauter
# QUESTION
# Donnez le sens général de la forme: ʒuboŋose
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋege
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋaŋe
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋosam
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋegam
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋaŋam
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋoso
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋego
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋaŋo
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋosar
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋegar
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋaŋar
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋosarun
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋegarun
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋaŋarun
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋosarim
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋegarim
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒuboŋaŋarim
# Réponse :
# REPONSE
# recouvrir
# QUESTION
# Donnez le sens général de la forme: ʒozutose
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutege
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutaŋe
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutosam
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutegam
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutaŋam
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutoso
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutego
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutaŋo
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutosar
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutegar
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutaŋar
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutosarun
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutegarun
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutaŋarun
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutosarim
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutegarim
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: ʒozutaŋarim
# Réponse :
# REPONSE
# donner
# QUESTION
# Donnez le sens général de la forme: guvonose
# Réponse :
# REPONSE
# chercher
# QUESTION
# Donnez le sens général de la forme: guvonege
# Réponse :
# REPONSE
# chercher
# QUESTION
# Donnez le sens général de la forme: guvonaŋe
# Réponse :
# REPONSE
# chercher
# QUESTION
# Donnez le sens général de la forme: guvonosam
# Réponse :
# REPONSE
# chercher
# QUESTION
# Donnez le sens général de la forme: guvonegam
# Réponse :
# REPONSE
# chercher
# QUESTION
# Donnez le sens général de la forme: guvonaŋam
# Réponse :
# REPONSE
# chercher
# QUESTION
# Donnez le sens général de la forme: guvonoso
# Réponse :
# REPONSE
# chercher
# QUESTION
# Donnez le sens général de la forme: guvonego
# Réponse :
# REPONSE
# chercher
# QUESTION
# Donnez le sens général de la forme: guvonaŋo
# Réponse :
# REPONSE
# chercher
# QUESTION
# Donnez le sens général de la forme: guvonosar
# Réponse :
# REPONSE
# chercher
# QUESTION
# Donnez le sens général de la forme: guvonegar
# Réponse :
# REPONSE
# chercher
# QUESTION
# ...
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Nom
#
# REPONSE
# ʃomuniaska
# QUESTION
# arbre
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Acc
#
# REPONSE
# moʃomunias
# QUESTION
# arbre
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Dat
#
# REPONSE
# ʃomuniasda
# QUESTION
# arbre
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Obl
#
# REPONSE
# ʃomuniaslo
# QUESTION
# arbre
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Nom
#
# REPONSE
# ʃomunioka
# QUESTION
# arbre
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Acc
#
# REPONSE
# moʃomunio
# QUESTION
# arbre
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Dat
#
# REPONSE
# ʃomunioda
# QUESTION
# arbre
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Obl
#
# REPONSE
# ʃomuniolo
# QUESTION
# souffrance
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Sg, Cas=Nom
#
# REPONSE
# lurudaeka
# QUESTION
# souffrance
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Sg, Cas=Acc
#
# REPONSE
# molurudae
# QUESTION
# souffrance
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Sg, Cas=Dat
#
# REPONSE
# lurudaeda
# QUESTION
# souffrance
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Sg, Cas=Obl
#
# REPONSE
# lurudaelo
# QUESTION
# souffrance
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Nom
#
# REPONSE
# lurudaaska
# QUESTION
# souffrance
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Acc
#
# REPONSE
# molurudaas
# QUESTION
# souffrance
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Dat
#
# REPONSE
# lurudaasda
# QUESTION
# souffrance
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Obl
#
# REPONSE
# lurudaaslo
# QUESTION
# souffrance
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Nom
#
# REPONSE
# lurudaoka
# QUESTION
# souffrance
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Acc
#
# REPONSE
# molurudao
# QUESTION
# souffrance
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Dat
#
# REPONSE
# lurudaoda
# QUESTION
# souffrance
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Obl
#
# REPONSE
# lurudaolo
# QUESTION
# villageois
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Sg, Cas=Nom
#
# REPONSE
# ponuðeka
# QUESTION
# villageois
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Sg, Cas=Acc
#
# REPONSE
# moponuðe
# QUESTION
# villageois
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Sg, Cas=Dat
#
# REPONSE
# ponuðeda
# QUESTION
# villageois
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Sg, Cas=Obl
#
# REPONSE
# ponuðelo
# QUESTION
# villageois
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Nom
#
# REPONSE
# ponuðaska
# QUESTION
# villageois
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Acc
#
# REPONSE
# moponuðas
# QUESTION
# villageois
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Dat
#
# REPONSE
# ponuðasda
# QUESTION
# villageois
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Obl
#
# REPONSE
# ponuðaslo
# QUESTION
# villageois
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Nom
#
# REPONSE
# ponuðoka
# QUESTION
# villageois
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Acc
#
# REPONSE
# moponuðo
# QUESTION
# villageois
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Dat
#
# REPONSE
# ponuðoda
# QUESTION
# villageois
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Obl
#
# REPONSE
# ponuðolo
# QUESTION
# mort
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Sg, Cas=Nom
#
# REPONSE
# foruteka
# QUESTION
# mort
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Sg, Cas=Acc
#
# REPONSE
# moforute
# QUESTION
# mort
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Sg, Cas=Dat
#
# REPONSE
# foruteda
# QUESTION
# mort
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Sg, Cas=Obl
#
# REPONSE
# forutelo
# QUESTION
# mort
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Nom
#
# REPONSE
# forutaska
# QUESTION
# mort
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Acc
#
# REPONSE
# moforutas
# QUESTION
# mort
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Dat
#
# REPONSE
# forutasda
# QUESTION
# mort
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Du, Cas=Obl
#
# REPONSE
# forutaslo
# QUESTION
# mort
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Nom
#
# REPONSE
# forutoka
# QUESTION
# mort
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Acc
#
# REPONSE
# moforuto
# QUESTION
# mort
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Dat
#
# REPONSE
# forutoda
# QUESTION
# mort
# QUESTION
# NOM, CF=N2,  Genre=M, Nombre=Pl, Cas=Obl
#
# REPONSE
# forutolo
# QUESTION
# maison
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Nom
#
# REPONSE
# zadumuloi
# QUESTION
# maison
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Acc
#
# REPONSE
# kodumuloi
# QUESTION
# maison
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Dat
#
# REPONSE
# fadumuloi
# QUESTION
# maison
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Obl
#
# REPONSE
# dumuloiaf
# QUESTION
# maison
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Nom
#
# REPONSE
# zadumuloel
# QUESTION
# maison
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Acc
#
# REPONSE
# kodumuloel
# QUESTION
# maison
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Dat
#
# REPONSE
# fadumuloel
# QUESTION
# maison
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Obl
#
# REPONSE
# dumuloelaf
# QUESTION
# maison
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Nom
#
# REPONSE
# zadumuloa
# QUESTION
# maison
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Acc
#
# REPONSE
# kodumuloa
# QUESTION
# maison
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Dat
#
# REPONSE
# fadumuloa
# QUESTION
# maison
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Obl
#
# REPONSE
# dumuloaaf
# QUESTION
# villageoise
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Nom
#
# REPONSE
# zaneθomi
# QUESTION
# villageoise
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Acc
#
# REPONSE
# koneθomi
# QUESTION
# villageoise
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Dat
#
# REPONSE
# faneθomi
# QUESTION
# villageoise
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Obl
#
# REPONSE
# neθomiaf
# QUESTION
# villageoise
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Nom
#
# REPONSE
# zaneθomel
# QUESTION
# villageoise
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Acc
#
# REPONSE
# koneθomel
# QUESTION
# villageoise
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Dat
#
# REPONSE
# faneθomel
# QUESTION
# villageoise
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Obl
#
# REPONSE
# neθomelaf
# QUESTION
# villageoise
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Nom
#
# REPONSE
# zaneθoma
# QUESTION
# villageoise
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Acc
#
# REPONSE
# koneθoma
# QUESTION
# villageoise
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Dat
#
# REPONSE
# faneθoma
# QUESTION
# villageoise
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Obl
#
# REPONSE
# neθomaaf
# QUESTION
# louve
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Nom
#
# REPONSE
# zavobuŋi
# QUESTION
# louve
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Acc
#
# REPONSE
# kovobuŋi
# QUESTION
# louve
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Dat
#
# REPONSE
# favobuŋi
# QUESTION
# louve
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Obl
#
# REPONSE
# vobuŋiaf
# QUESTION
# louve
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Nom
#
# REPONSE
# zavobuŋel
# QUESTION
# louve
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Acc
#
# REPONSE
# kovobuŋel
# QUESTION
# louve
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Dat
#
# REPONSE
# favobuŋel
# QUESTION
# louve
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Obl
#
# REPONSE
# vobuŋelaf
# QUESTION
# louve
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Nom
#
# REPONSE
# zavobuŋa
# QUESTION
# louve
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Acc
#
# REPONSE
# kovobuŋa
# QUESTION
# louve
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Dat
#
# REPONSE
# favobuŋa
# QUESTION
# louve
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Obl
#
# REPONSE
# vobuŋaaf
# QUESTION
# Violette
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Nom
#
# REPONSE
# zavjoleti
# QUESTION
# Violette
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Acc
#
# REPONSE
# kovjoleti
# QUESTION
# Violette
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Dat
#
# REPONSE
# favjoleti
# QUESTION
# Violette
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Obl
#
# REPONSE
# vjoletiaf
# QUESTION
# Violette
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Nom
#
# REPONSE
# zavjoletel
# QUESTION
# Violette
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Acc
#
# REPONSE
# kovjoletel
# QUESTION
# Violette
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Dat
#
# REPONSE
# favjoletel
# QUESTION
# Violette
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Obl
#
# REPONSE
# vjoletelaf
# QUESTION
# Violette
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Nom
#
# REPONSE
# zavjoleta
# QUESTION
# Violette
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Acc
#
# REPONSE
# kovjoleta
# QUESTION
# Violette
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Dat
#
# REPONSE
# favjoleta
# QUESTION
# Violette
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Obl
#
# REPONSE
# vjoletaaf
# QUESTION
# combattant
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Nom
#
# REPONSE
# zapowori
# QUESTION
# combattant
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Acc
#
# REPONSE
# kopowori
# QUESTION
# combattant
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Dat
#
# REPONSE
# fapowori
# QUESTION
# combattant
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Obl
#
# REPONSE
# poworiaf
# QUESTION
# combattant
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Nom
#
# REPONSE
# zapoworel
# QUESTION
# combattant
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Acc
#
# REPONSE
# kopoworel
# QUESTION
# combattant
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Dat
#
# REPONSE
# fapoworel
# QUESTION
# combattant
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Obl
#
# REPONSE
# poworelaf
# QUESTION
# combattant
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Nom
#
# REPONSE
# zapowora
# QUESTION
# combattant
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Acc
#
# REPONSE
# kopowora
# QUESTION
# combattant
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Dat
#
# REPONSE
# fapowora
# QUESTION
# combattant
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Obl
#
# REPONSE
# poworaaf
# QUESTION
# fille
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Nom
#
# REPONSE
# zamotuji
# QUESTION
# fille
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Acc
#
# REPONSE
# komotuji
# QUESTION
# fille
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Dat
#
# REPONSE
# famotuji
# QUESTION
# fille
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Sg, Cas=Obl
#
# REPONSE
# motujiaf
# QUESTION
# fille
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Nom
#
# REPONSE
# zamotujel
# QUESTION
# fille
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Acc
#
# REPONSE
# komotujel
# QUESTION
# fille
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Dat
#
# REPONSE
# famotujel
# QUESTION
# fille
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Du, Cas=Obl
#
# REPONSE
# motujelaf
# QUESTION
# fille
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Nom
#
# REPONSE
# zamotuja
# QUESTION
# fille
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Acc
#
# REPONSE
# komotuja
# QUESTION
# fille
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Dat
#
# REPONSE
# famotuja
# QUESTION
# fille
# QUESTION
# NOM, CF=N1,  Genre=F, Nombre=Pl, Cas=Obl
#
# REPONSE
# motujaaf
# QUESTION
# lune
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Nom
#
# REPONSE
# giʒoloeka
# QUESTION
# lune
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Acc
#
# REPONSE
# mogiʒoloe
# QUESTION
# lune
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Dat
#
# REPONSE
# giʒoloeda
# QUESTION
# lune
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Obl
#
# REPONSE
# giʒoloelo
# QUESTION
# lune
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Nom
#
# REPONSE
# giʒoloaska
# QUESTION
# lune
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Acc
#
# REPONSE
# mogiʒoloas
# QUESTION
# lune
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Dat
#
# REPONSE
# giʒoloasda
# QUESTION
# lune
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Obl
#
# REPONSE
# giʒoloaslo
# QUESTION
# lune
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Nom
#
# REPONSE
# giʒolooka
# QUESTION
# lune
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Acc
#
# REPONSE
# mogiʒoloo
# QUESTION
# lune
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Dat
#
# REPONSE
# giʒolooda
# QUESTION
# lune
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Obl
#
# REPONSE
# giʒoloolo
# QUESTION
# forêt
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Nom
#
# REPONSE
# ronugueka
# QUESTION
# forêt
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Acc
#
# REPONSE
# moronugue
# QUESTION
# forêt
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Dat
#
# REPONSE
# ronugueda
# QUESTION
# forêt
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Obl
#
# REPONSE
# ronuguelo
# QUESTION
# forêt
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Nom
#
# REPONSE
# ronuguaska
# QUESTION
# forêt
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Acc
#
# REPONSE
# moronuguas
# QUESTION
# forêt
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Dat
#
# REPONSE
# ronuguasda
# QUESTION
# forêt
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Obl
#
# REPONSE
# ronuguaslo
# QUESTION
# forêt
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Nom
#
# REPONSE
# ronuguoka
# QUESTION
# forêt
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Acc
#
# REPONSE
# moronuguo
# QUESTION
# forêt
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Dat
#
# REPONSE
# ronuguoda
# QUESTION
# forêt
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Obl
#
# REPONSE
# ronuguolo
# QUESTION
# sort
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Nom
#
# REPONSE
# mobuzoeka
# QUESTION
# sort
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Acc
#
# REPONSE
# momobuzoe
# QUESTION
# sort
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Dat
#
# REPONSE
# mobuzoeda
# QUESTION
# sort
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Obl
#
# REPONSE
# mobuzoelo
# QUESTION
# sort
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Nom
#
# REPONSE
# mobuzoaska
# QUESTION
# sort
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Acc
#
# REPONSE
# momobuzoas
# QUESTION
# sort
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Dat
#
# REPONSE
# mobuzoasda
# QUESTION
# sort
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Obl
#
# REPONSE
# mobuzoaslo
# QUESTION
# sort
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Nom
#
# REPONSE
# mobuzooka
# QUESTION
# sort
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Acc
#
# REPONSE
# momobuzoo
# QUESTION
# sort
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Dat
#
# REPONSE
# mobuzooda
# QUESTION
# sort
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Obl
#
# REPONSE
# mobuzoolo
# QUESTION
# Mahira
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Nom
#
# REPONSE
# mairaeka
# QUESTION
# Mahira
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Acc
#
# REPONSE
# momairae
# QUESTION
# Mahira
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Dat
#
# REPONSE
# mairaeda
# QUESTION
# Mahira
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Obl
#
# REPONSE
# mairaelo
# QUESTION
# Mahira
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Nom
#
# REPONSE
# mairaaska
# QUESTION
# Mahira
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Acc
#
# REPONSE
# momairaas
# QUESTION
# Mahira
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Dat
#
# REPONSE
# mairaasda
# QUESTION
# Mahira
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Obl
#
# REPONSE
# mairaaslo
# QUESTION
# Mahira
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Nom
#
# REPONSE
# mairaoka
# QUESTION
# Mahira
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Acc
#
# REPONSE
# momairao
# QUESTION
# Mahira
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Dat
#
# REPONSE
# mairaoda
# QUESTION
# Mahira
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Obl
#
# REPONSE
# mairaolo
# QUESTION
# nuit
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Nom
#
# REPONSE
# robukueka
# QUESTION
# nuit
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Acc
#
# REPONSE
# morobukue
# QUESTION
# nuit
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Dat
#
# REPONSE
# robukueda
# QUESTION
# nuit
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Obl
#
# REPONSE
# robukuelo
# QUESTION
# nuit
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Nom
#
# REPONSE
# robukuaska
# QUESTION
# nuit
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Acc
#
# REPONSE
# morobukuas
# QUESTION
# nuit
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Dat
#
# REPONSE
# robukuasda
# QUESTION
# nuit
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Obl
#
# REPONSE
# robukuaslo
# QUESTION
# nuit
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Nom
#
# REPONSE
# robukuoka
# QUESTION
# nuit
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Acc
#
# REPONSE
# morobukuo
# QUESTION
# nuit
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Dat
#
# REPONSE
# robukuoda
# QUESTION
# nuit
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Obl
#
# REPONSE
# robukuolo
# QUESTION
# ombre
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Nom
#
# REPONSE
# doduleka
# QUESTION
# ombre
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Acc
#
# REPONSE
# mododule
# QUESTION
# ombre
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Dat
#
# REPONSE
# doduleda
# QUESTION
# ombre
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Sg, Cas=Obl
#
# REPONSE
# dodulelo
# QUESTION
# ombre
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Nom
#
# REPONSE
# dodulaska
# QUESTION
# ombre
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Acc
#
# REPONSE
# mododulas
# QUESTION
# ombre
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Dat
#
# REPONSE
# dodulasda
# QUESTION
# ombre
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Du, Cas=Obl
#
# REPONSE
# dodulaslo
# QUESTION
# ombre
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Nom
#
# REPONSE
# doduloka
# QUESTION
# ombre
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Acc
#
# REPONSE
# mododulo
# QUESTION
# ombre
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Dat
#
# REPONSE
# doduloda
# QUESTION
# ombre
# QUESTION
# NOM, CF=N2,  Genre=F, Nombre=Pl, Cas=Obl
#
# REPONSE
# dodulolo

# %%
#print xmlFichier

# %%
#questionsConsigne.getConsigne(donnees)

# %%
#print xmlOutput.getXML()

# %%
clozes
# Out:
# {u'#1#': u'TXT',
#  u'#10#': u'TXT',
#  u'#11#': u'TXT',
#  u'#12#': u'TXT',
#  u'#2#': u'TXT',
#  u'#3#': u'TXT',
#  u'#4#': u'TXT',
#  u'#5#': u'TXT',
#  u'#6#': u'SAC',
#  u'#7#': u'TXT',
#  u'#8#': u'TXT',
#  u'#9#': u'TXT'}
