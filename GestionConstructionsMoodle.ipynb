# %%
import pandas as pd
import codecs

# %%
encoding="utf8"
repertoire="/Users/gilles/ownCloud/Python/Moodle/Cloze/Cloze-Template/Morphologie/"
fichier="Cloze-Exceptions.txt"
commentaire="#"
separateur=";"

# %%
with codecs.open(repertoire+fichier,"r",encoding=encoding) as input:
    lignes=input.readlines()

# %%
donnees=[]
lignesEntrainement=[]
lignesEvaluation=[]
for ligne in lignes[:]:
    ligne=ligne.strip()
    if not ligne.startswith(commentaire) and not ligne=="":
        donnees.append(ligne.split(separateur))
    elif ligne.startswith(commentaire) and not ligne=="#EX;":
        lignesEntrainement.append(ligne)
        lignesEvaluation.append(ligne)

# %% [raw]
# tableau=pd.DataFrame(donnees)
# tableau.to_csv(path_or_buf=repertoire+fichier.replace(".txt",".csv"),encoding="utf8",sep=";")

# %%
extTableau=pd.read_csv(filepath_or_buffer=repertoire+fichier.replace(".txt",".csv"),encoding="utf8",sep=";")

# %%
entrainements=[]
evaluations=[]
for groupe, data in extTableau.groupby(by=[u"Sémantique","Phono"]):
    entrainements.append(data[0:len(data)/2])
#    print data[0:len(data)/2]
    evaluations.append(data[len(data)/2:])
#    print data[len(data)/2:]
entrainement=pd.concat(entrainements, ignore_index=True)
evaluation=pd.concat(evaluations, ignore_index=True)

# %%
entrainement.groupby(by=[u"Sémantique","Phono"]).count()[[u"DÉRIVÉ"]]
# Out:
#                                                           DÉRIVÉ
# Sémantique                             Phono
# Agent ou Instrument de BASE            radical.IMPF+œr         1
#                                        radical.savant+œr       1
# Agent ou Instrument qui VERBE les NOMS verbe.PRS.SG-nom        1
# BASE BASÉE                             mot-valisage            1
# BASE en lexème                         univerbation            1
# BASE en registre populaire             apocope+Vʃ              2
# BASE en sigle                          siglaison               4
# action de BASER                        radical.PST+t+jɔ̃       2
# bibliothèque de BASE                   radical+otɛk            2
# contraire de BASE                      ɛ̃+radical              1
# de manière BASE                        radical+mɑ̃             1
# diminutif de BASE                      gabarit CVCV            2
#                                        infixe -in-             1
#                                        rVCVCV                  2
#                                        radical+ɔ̃              1
#                                        radical+ɛt              1
# en tant que BASE                       radical+mɑ̃             2
# inverse de BASER                       de+radical              1
# métier en rapport avec BASE            radical+je              4
#                                        radical+œr              1
# particularité d'être BASE              radical+ityd            2
# plante à BASE                          radical+je              1
# propriété d'être BASE                  radical.F+ite           1
# qui peut être BASÉ                     radical.IMPF+abl        2
# relationnel de BASE                    radical+ik              1
#                                        radical+ɛsk             1
#                                        radical.savant+ɛr       1
# rendre BASE                            radical+ifi             3
#                                        radical+iz              1
# se poser sur BASE                      a+radical+i             1
# sportif qui pratique la BASE           radical+man             1
#                                        radical+œr              2
# taux de BASE                           radical+alite           1

# %%
evaluation.groupby(by=[u"Sémantique","Phono"]).count()[[u"DÉRIVÉ"]]
# Out:
#                                                           DÉRIVÉ
# Sémantique                             Phono
# Agent ou Instrument de BASE            radical.IMPF+œr         1
#                                        radical.savant+œr       1
# Agent ou Instrument qui VERBE les NOMS verbe.PRS.SG-nom        1
# BASE BASÉE                             mot-valisage            1
# BASE en lexème                         univerbation            2
# BASE en registre populaire             apocope+Vʃ              3
# BASE en sigle                          siglaison               5
# BASER                                  réanalyse               1
# action de BASER                        radical.PST+t+jɔ̃       2
# bibliothèque de BASE                   radical+otɛk            3
# collectif de BASE                      radical+je              1
# contraire de BASE                      ɛ̃+radical              1
# de manière BASE                        radical+mɑ̃             1
# diminutif de BASE                      gabarit CVCV            2
#                                        infixe -in-             2
#                                        infixe -ɛl-             1
#                                        rVCVCV                  2
#                                        radical+jɛr             1
#                                        radical+ɔ̃              1
#                                        radical+ɛt              2
# en tant que BASE                       radical+mɑ̃             3
# inverse de BASER                       de+radical              1
# métier en rapport avec BASE            radical+je              4
#                                        radical+œr              1
# particularité d'être BASE              radical+ityd            2
# plante à BASE                          radical+je              1
# propriété d'être BASE                  radical.F+ite           1
# qui peut être BASÉ                     radical+abl             1
#                                        radical.IMPF+abl        3
# relationnel de BASE                    radical+ik              2
#                                        radical+ɛsk             1
#                                        radical.savant+ɛr       1
# rendre BASE                            radical+ifi             3
#                                        radical+iz              1
# résultat de BASER                      radical.IMPF+ri         1
# se poser sur BASE                      a+radical+i             1
# sportif qui pratique la BASE           radical+man             1
#                                        radical+œr              2
# taux de BASE                           radical+alite           1

# %%
for num,row in entrainement.iterrows():
    lignesEntrainement.append(u"#EX")
    lignesEntrainement.append(u";".join(row.tolist()))
for num,row in evaluation.iterrows():
    lignesEvaluation.append("#EX")
    lignesEvaluation.append(u";".join(row.tolist()))

# %%
with codecs.open(repertoire+fichier.replace(".txt","-Entrainement.txt"),"w",encoding=encoding) as output:
    output.write("\n".join(lignesEntrainement))

# %%
with codecs.open(repertoire+fichier.replace(".txt","-Evaluation.txt"),"w",encoding=encoding) as output:
    output.write("\n".join(lignesEvaluation))
